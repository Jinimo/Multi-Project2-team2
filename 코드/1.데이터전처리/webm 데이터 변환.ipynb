# %%
import librosa
import sklearn
import cv2
import numpy as np
import IPython.display as ipd
import matplotlib.pyplot as plt
import librosa.display
import os
import pandas as pd

# %%
# !pip install ffmpeg-python
# Out:
# ...
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\envs\kdig\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\envs\kdig\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\envs\kdig\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\envs\kdig\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\envs\kdig\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\envs\kdig\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\envs\kdig\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'D:\ANACONDA\envs\kdig\python.exe -m pip install --upgrade pip' command.

# %%
from os import path
import os
from pydub import AudioSegment
from pydub.utils import make_chunks
filepath='C:/Users/jhgf/Desktop/multicampus/multicampus/2차 세미프로젝트/주제 뽑기/기침 이용한 코로나 분석/public_dataset/public_dataset/'
filelist=os.listdir(filepath)

for name in filelist:
    if name.split(".")[-1]=='json':
        pass
    else:
        newname=name.split(".")[0]
        audioSegment = AudioSegment.from_file(filepath+name)
        audioSegment.export('./'+newname+'.wav', format='wav')
# Out:
# ['00014dcc-0f06-4c27-8c7b-737b18a2cf4c.json',
#  '00014dcc-0f06-4c27-8c7b-737b18a2cf4c.webm',
#  '00039425-7f3a-42aa-ac13-834aaa2b6b92.json',
#  '00039425-7f3a-42aa-ac13-834aaa2b6b92.webm',
#  '0007c6f1-5441-40e6-9aaf-a761d8f2da3b.json',
#  '0007c6f1-5441-40e6-9aaf-a761d8f2da3b.webm',
#  '0009eb28-d8be-4dc1-92bb-907e53bc5c7a.json',
#  '0009eb28-d8be-4dc1-92bb-907e53bc5c7a.webm',
#  '0012c608-33d0-4ef7-bde3-75a0b1a0024e.json',
#  '0012c608-33d0-4ef7-bde3-75a0b1a0024e.webm',
#  '001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f.json',
#  '001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f.webm',
#  '001c85a8-cc4d-4921-9297-848be52d4715.json',
#  '001c85a8-cc4d-4921-9297-848be52d4715.webm',
#  '001d8e33-a4af-4edb-98ba-b03f891d9a6c.json',
#  '001d8e33-a4af-4edb-98ba-b03f891d9a6c.webm',
#  '001e2f19-d81c-4029-b33c-d2db56b23a4a.json',
#  '001e2f19-d81c-4029-b33c-d2db56b23a4a.webm',
#  '00273cdf-ed90-4105-84ec-0c88d52f1dc0.json',
#  '00273cdf-ed90-4105-84ec-0c88d52f1dc0.webm',
# ...

# %%
len(filelist)
