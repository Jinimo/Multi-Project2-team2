# %%
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.12)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, Concatenate, GlobalAveragePooling2D
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import pickle5 as pickle
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf
seed=2022
tf.random.set_seed(seed)
np.random.seed(seed)

# %% [markdown]
# # mfcc

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/mfcc/mfcc_lst_test.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data=np.array(result)
result_data.shape
# Out:
# (2076, 30, 901)

# %% [markdown]
# # codiv-19, feature

# %%
y = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/mfcc/Y_data_test.csv").iloc[:,0].values

# %%
features = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/csv파일/df_1565_test2.csv")
features = features.iloc[:,[4,5,6,7]]
feature_lst = []
for i in features.index:
    for _ in range(4):
        feature_lst.append(features.iloc[i,:].values)
features = pd.DataFrame(feature_lst)
features.shape
# Out:
# (2076, 4)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    result_data, features, stratify = features, test_size = 0.2
)

# %%
features_train = Y_train.iloc[:,:-1].values
y_data_train = Y_train.iloc[:,-1].values

# %%
features_test = Y_test.iloc[:,:-1].values
y_data_test = Y_test.iloc[:,-1].values

# %%
# 각 입력에 대한 형태를 명시
img_input = Input(shape = (30,901,1), name = "features_train")
form_input = Input(shape = (3,), name = "y_data_train")

# %%
# 이미지 입력
x_1 = Conv2D(128, (3,3), activation = "relu")(img_input)
x_1 = Conv2D(128, (3,3), activation = "relu")(x_1)
x_1 = MaxPooling2D(strides = 2)(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = Conv2D(64, (3,3), activation='relu')(x_1)
x_1 = Conv2D(64, (3,3), activation='relu')(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = GlobalAveragePooling2D()(x_1)

# 피쳐 입력
x_2 = Dense(128, input_dim = 3 ,activation  = "relu")(form_input)
x_2 = Dense(32, activation = "relu")(x_2)

x = Concatenate()([x_1, x_2])
rate_pred = Dense(1, name = "covid", activation = "sigmoid")(x)

# %%
model = Model(inputs = [img_input, form_input],
              outputs = [rate_pred])

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  features_train (InputLayer)    [(None, 30, 901, 1)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 28, 899, 128  1280        ['features_train[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 26, 897, 128  147584      ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 13, 448, 128  0           ['conv2d_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 13, 448, 128  0           ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 11, 446, 64)  73792       ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 9, 444, 64)   36928       ['conv2d_2[0][0]']
#
#  y_data_train (InputLayer)      [(None, 3)]          0           []
#
#  dropout_1 (Dropout)            (None, 9, 444, 64)   0           ['conv2d_3[0][0]']
#
#  dense (Dense)                  (None, 128)          512         ['y_data_train[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['dropout_1[0][0]']
#  alAveragePooling2D)
#
#  dense_1 (Dense)                (None, 32)           4128        ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['global_average_pooling2d[0][0]'
#                                                                  , 'dense_1[0][0]']
#
#  covid (Dense)                  (None, 1)            97          ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 264,321
# Trainable params: 264,321
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop
rmsp = RMSprop(learning_rate=0.001, rho=0.9, epsilon=None, decay=0.0)

# %%
model.compile(optimizer = rmsp,
              loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
model_path = "functional-first.h5"
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1, monitor = "val_accuracy")
es = EarlyStopping(patience=10, monitor = "val_accuracy")

# %%
hist = model.fit([X_train, features_train] , y_data_train,
                 epochs = 100, batch_size = 150,
                 validation_split=0.2, callbacks = [es, mc])
# Out:
# Epoch 1/100
# 9/9 [==============================] - ETA: 0s - loss: 1.9307 - accuracy: 0.5241
# Epoch 1: val_accuracy improved from -inf to 0.57530, saving model to functional-first.h5
# 9/9 [==============================] - 37s 2s/step - loss: 1.9307 - accuracy: 0.5241 - val_loss: 0.6794 - val_accuracy: 0.5753
# Epoch 2/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6849 - accuracy: 0.5527
# Epoch 2: val_accuracy improved from 0.57530 to 0.60241, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6849 - accuracy: 0.5527 - val_loss: 0.6630 - val_accuracy: 0.6024
# Epoch 3/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6694 - accuracy: 0.5655
# Epoch 3: val_accuracy improved from 0.60241 to 0.62651, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6694 - accuracy: 0.5655 - val_loss: 0.6578 - val_accuracy: 0.6265
# Epoch 4/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6585 - accuracy: 0.5851
# Epoch 4: val_accuracy did not improve from 0.62651
# 9/9 [==============================] - 10s 1s/step - loss: 0.6585 - accuracy: 0.5851 - val_loss: 0.6440 - val_accuracy: 0.5723
# Epoch 5/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6529 - accuracy: 0.5873
# Epoch 5: val_accuracy did not improve from 0.62651
# 9/9 [==============================] - 10s 1s/step - loss: 0.6529 - accuracy: 0.5873 - val_loss: 0.6345 - val_accuracy: 0.5994
# Epoch 6/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6451 - accuracy: 0.5836
# Epoch 6: val_accuracy improved from 0.62651 to 0.65361, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6451 - accuracy: 0.5836 - val_loss: 0.6293 - val_accuracy: 0.6536
# Epoch 7/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6367 - accuracy: 0.6227
# Epoch 7: val_accuracy did not improve from 0.65361
# 9/9 [==============================] - 10s 1s/step - loss: 0.6367 - accuracy: 0.6227 - val_loss: 0.6234 - val_accuracy: 0.6506
# Epoch 8/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6346 - accuracy: 0.6062
# Epoch 8: val_accuracy improved from 0.65361 to 0.66265, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6346 - accuracy: 0.6062 - val_loss: 0.6214 - val_accuracy: 0.6627
# Epoch 9/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6302 - accuracy: 0.6242
# Epoch 9: val_accuracy improved from 0.66265 to 0.67169, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6302 - accuracy: 0.6242 - val_loss: 0.6200 - val_accuracy: 0.6717
# Epoch 10/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6294 - accuracy: 0.6212
# Epoch 10: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6294 - accuracy: 0.6212 - val_loss: 0.6874 - val_accuracy: 0.5904
# Epoch 11/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6373 - accuracy: 0.6167
# Epoch 11: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6373 - accuracy: 0.6167 - val_loss: 0.6174 - val_accuracy: 0.6295
# Epoch 12/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6268 - accuracy: 0.6250
# Epoch 12: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6268 - accuracy: 0.6250 - val_loss: 0.6180 - val_accuracy: 0.6265
# Epoch 13/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6304 - accuracy: 0.6205
# Epoch 13: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6304 - accuracy: 0.6205 - val_loss: 0.6249 - val_accuracy: 0.6295
# Epoch 14/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6265 - accuracy: 0.6273
# Epoch 14: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6265 - accuracy: 0.6273 - val_loss: 0.6136 - val_accuracy: 0.6416
# Epoch 15/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6270 - accuracy: 0.6212
# Epoch 15: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6270 - accuracy: 0.6212 - val_loss: 0.6149 - val_accuracy: 0.6295
# Epoch 16/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6249 - accuracy: 0.6280
# Epoch 16: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6249 - accuracy: 0.6280 - val_loss: 0.6133 - val_accuracy: 0.6325
# Epoch 17/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6244 - accuracy: 0.6288
# Epoch 17: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6244 - accuracy: 0.6288 - val_loss: 0.6122 - val_accuracy: 0.6325
# Epoch 18/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6314 - accuracy: 0.6212
# Epoch 18: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6314 - accuracy: 0.6212 - val_loss: 0.6123 - val_accuracy: 0.6325
# Epoch 19/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6485 - accuracy: 0.6227
# Epoch 19: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6485 - accuracy: 0.6227 - val_loss: 0.6125 - val_accuracy: 0.6386

# %%
best_model = load_model(model_path)
best_model.evaluate([X_test, features_test], y_data_test)
# Out:
# 13/13 [==============================] - 1s 66ms/step - loss: 0.6265 - accuracy: 0.6370
# [0.6264985799789429, 0.6370192170143127]

# %%
import matplotlib.pyplot as plt

y_acc = hist.history["val_accuracy"]
y_vloss = hist.history["val_loss"]
xs = np.arange(1, len(y_acc) + 1)

plt.figure(figsize = (12,8))
plt.plot(xs, y_acc, label = "Validation Accuracy")
plt.plot(xs, y_vloss, label = "Validation loss")
plt.legend(), plt.grid(), plt.xlabel("Epoch"), plt.title("functional First"), plt.ylim([0.4,1])
plt.show()

# %%
from sklearn.metrics import confusion_matrix
y_train_pred=best_model.predict([X_test, features_test])
yhat=[]
for data in y_train_pred:
  if data>=0.5:
    yhat.append(1)
  else:
    yhat.append(0)
yhat

# %%
cf = confusion_matrix(y_data_test, yhat)
print(cf)
# Out:
# [[125  59]
#  [ 92 140]]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
p = precision_score(y_data_test, yhat)
print(p)
r = recall_score(y_data_test, yhat)
print(r)
f1 = f1_score(y_data_test, yhat)
print(f1)
# Out:
# 0.7035175879396985
# 0.603448275862069
# 0.6496519721577727

# %% [markdown]
# # train_test dataset에 없는 다른 데이터로 모델 테스트

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/test/fffff.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data_other=np.array(result)
result_data_other.shape
# Out:
# (520, 30, 901)

# %%
features_other = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/test/test_df_15세65세_aug전.csv")
features_other = features_other.iloc[:,[4,5,6,7]]
features_other
# Out:
#      man  respiratory_condition  fever_muscle_pain  COVID-19
# 0      1                      1                  0         0
# 1      1                      1                  0         0
# 2      1                      0                  0         0
# 3      1                      0                  0         0
# 4      1                      0                  0         0
# ..   ...                    ...                ...       ...
# 515    0                      0                  1         1
# 516    0                      0                  0         1
# 517    0                      0                  0         1
# 518    0                      0                  1         1
# 519    0                      0                  1         1
#
# [520 rows x 4 columns]

# %%
feature_test_data = features_other.iloc[:,:-1].values
y_test_data = features_other.iloc[:,-1].values

# %%
y_train_pred=model.predict([result_data_other, feature_test_data])
yhat_test=[]
for data in y_train_pred:
  if data>=0.5:
    yhat_test.append(1)
  else:
    yhat_test.append(0)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
p = precision_score(y_test_data, yhat_test)
print(p)
r = recall_score(y_test_data, yhat_test)
print(r)
f1 = f1_score(y_test_data, yhat_test)
print(f1)
# Out:
# 0.49889135254988914
# 0.8653846153846154
# 0.6329113924050632

# %%
model.evaluate([result_data_other, feature_test_data], y_test_data)
# Out:
# 17/17 [==============================] - 1s 61ms/step - loss: 0.7294 - accuracy: 0.4981
# [0.729433000087738, 0.4980769157409668]
