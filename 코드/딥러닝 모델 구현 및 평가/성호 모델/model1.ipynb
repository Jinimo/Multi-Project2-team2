# %%
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.12)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, Concatenate, GlobalAveragePooling2D
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import pickle5 as pickle
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf
seed=2022
tf.random.set_seed(seed)
np.random.seed(seed)

# %% [markdown]
# # mfcc

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/mfcc/mfcc_lst_test.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data=np.array(result)
result_data.shape
# Out:
# (2076, 30, 901)

# %% [markdown]
# # codiv-19, feature

# %%
y = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/mfcc/Y_data_test.csv").iloc[:,0].values

# %%
features = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/csv파일/df_1565_test2.csv")
features = features.iloc[:,[4,5,6,7]]
feature_lst = []
for i in features.index:
    for _ in range(4):
        feature_lst.append(features.iloc[i,:].values)
features = pd.DataFrame(feature_lst)
features.shape
# Out:
# (2076, 4)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    result_data, features, stratify = features, test_size = 0.2
)

# %%
features_train = Y_train.iloc[:,:-1].values
y_data_train = Y_train.iloc[:,-1].values

# %%
features_test = Y_test.iloc[:,:-1].values
y_data_test = Y_test.iloc[:,-1].values

# %%
# 각 입력에 대한 형태를 명시
img_input = Input(shape = (30,901,1), name = "features_train")
form_input = Input(shape = (3,), name = "y_data_train")

# %%
# 이미지 입력
x_1 = Conv2D(128, (3,3), activation = "relu")(img_input)
x_1 = Conv2D(128, (3,3), activation = "relu")(x_1)
x_1 = MaxPooling2D(strides = 2)(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = Conv2D(64, (3,3), activation='relu')(x_1)
x_1 = Conv2D(64, (3,3), activation='relu')(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = GlobalAveragePooling2D()(x_1)

# 피쳐 입력
x_2 = Dense(128, input_dim = 3 ,activation  = "relu")(form_input)
# x_2 = Dense(32, activation = "relu")(form_input)   이쪽 DNN에서 dense층이 하나가 없어지는게 recall score 향상에 큰 도움을 줌

x = Concatenate()([x_1, x_2])
rate_pred = Dense(1, name = "covid", activation = "sigmoid")(x)

# %%
model = Model(inputs = [img_input, form_input],
              outputs = [rate_pred])

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  features_train (InputLayer)    [(None, 30, 901, 1)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 28, 899, 128  1280        ['features_train[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 26, 897, 128  147584      ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 13, 448, 128  0           ['conv2d_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 13, 448, 128  0           ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 11, 446, 64)  73792       ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 9, 444, 64)   36928       ['conv2d_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 9, 444, 64)   0           ['conv2d_3[0][0]']
#
#  y_data_train (InputLayer)      [(None, 3)]          0           []
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['dropout_1[0][0]']
#  alAveragePooling2D)
#
#  dense_1 (Dense)                (None, 32)           128         ['y_data_train[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['global_average_pooling2d[0][0]'
#                                                                  , 'dense_1[0][0]']
#
#  covid (Dense)                  (None, 1)            97          ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 259,809
# Trainable params: 259,809
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = "adam",
              loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
model_path = "functional-first.h5"
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1, monitor = "val_accuracy")
es = EarlyStopping(patience=10, monitor = "val_accuracy")

# %%
hist = model.fit([X_train, features_train] , y_data_train,
                 epochs = 100, batch_size = 150,
                 validation_split=0.2, callbacks = [es, mc])
# Out:
# Epoch 1/100
# 9/9 [==============================] - ETA: 0s - loss: 0.7573 - accuracy: 0.5113
# Epoch 1: val_accuracy improved from -inf to 0.57530, saving model to functional-first.h5
# 9/9 [==============================] - 40s 2s/step - loss: 0.7573 - accuracy: 0.5113 - val_loss: 0.6802 - val_accuracy: 0.5753
# Epoch 2/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6812 - accuracy: 0.5512
# Epoch 2: val_accuracy improved from 0.57530 to 0.58133, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6812 - accuracy: 0.5512 - val_loss: 0.6759 - val_accuracy: 0.5813
# Epoch 3/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6779 - accuracy: 0.5550
# Epoch 3: val_accuracy improved from 0.58133 to 0.58434, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6779 - accuracy: 0.5550 - val_loss: 0.6716 - val_accuracy: 0.5843
# Epoch 4/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6754 - accuracy: 0.5474
# Epoch 4: val_accuracy did not improve from 0.58434
# 9/9 [==============================] - 10s 1s/step - loss: 0.6754 - accuracy: 0.5474 - val_loss: 0.6704 - val_accuracy: 0.5693
# Epoch 5/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6718 - accuracy: 0.5527
# Epoch 5: val_accuracy did not improve from 0.58434
# 9/9 [==============================] - 10s 1s/step - loss: 0.6718 - accuracy: 0.5527 - val_loss: 0.6653 - val_accuracy: 0.5813
# Epoch 6/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6695 - accuracy: 0.5520
# Epoch 6: val_accuracy did not improve from 0.58434
# 9/9 [==============================] - 10s 1s/step - loss: 0.6695 - accuracy: 0.5520 - val_loss: 0.6630 - val_accuracy: 0.5783
# Epoch 7/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6665 - accuracy: 0.5512
# Epoch 7: val_accuracy improved from 0.58434 to 0.59639, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6665 - accuracy: 0.5512 - val_loss: 0.6601 - val_accuracy: 0.5964
# Epoch 8/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6639 - accuracy: 0.5520
# Epoch 8: val_accuracy improved from 0.59639 to 0.61446, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6639 - accuracy: 0.5520 - val_loss: 0.6555 - val_accuracy: 0.6145
# Epoch 9/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6620 - accuracy: 0.5610
# Epoch 9: val_accuracy did not improve from 0.61446
# 9/9 [==============================] - 10s 1s/step - loss: 0.6620 - accuracy: 0.5610 - val_loss: 0.6565 - val_accuracy: 0.5904
# Epoch 10/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6593 - accuracy: 0.5617
# Epoch 10: val_accuracy did not improve from 0.61446
# 9/9 [==============================] - 10s 1s/step - loss: 0.6593 - accuracy: 0.5617 - val_loss: 0.6488 - val_accuracy: 0.5934
# Epoch 11/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6556 - accuracy: 0.5693
# Epoch 11: val_accuracy did not improve from 0.61446
# 9/9 [==============================] - 10s 1s/step - loss: 0.6556 - accuracy: 0.5693 - val_loss: 0.6484 - val_accuracy: 0.6084
# Epoch 12/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6528 - accuracy: 0.5791
# Epoch 12: val_accuracy improved from 0.61446 to 0.61747, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6528 - accuracy: 0.5791 - val_loss: 0.6445 - val_accuracy: 0.6175
# Epoch 13/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6497 - accuracy: 0.5889
# Epoch 13: val_accuracy did not improve from 0.61747
# 9/9 [==============================] - 10s 1s/step - loss: 0.6497 - accuracy: 0.5889 - val_loss: 0.6404 - val_accuracy: 0.6084
# Epoch 14/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6468 - accuracy: 0.5979
# Epoch 14: val_accuracy did not improve from 0.61747
# 9/9 [==============================] - 10s 1s/step - loss: 0.6468 - accuracy: 0.5979 - val_loss: 0.6383 - val_accuracy: 0.6175
# Epoch 15/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6439 - accuracy: 0.6107
# Epoch 15: val_accuracy improved from 0.61747 to 0.62952, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6439 - accuracy: 0.6107 - val_loss: 0.6342 - val_accuracy: 0.6295
# Epoch 16/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6413 - accuracy: 0.6197
# Epoch 16: val_accuracy improved from 0.62952 to 0.65964, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6413 - accuracy: 0.6197 - val_loss: 0.6294 - val_accuracy: 0.6596
# Epoch 17/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6436 - accuracy: 0.6024
# Epoch 17: val_accuracy did not improve from 0.65964
# 9/9 [==============================] - 10s 1s/step - loss: 0.6436 - accuracy: 0.6024 - val_loss: 0.6330 - val_accuracy: 0.6325
# Epoch 18/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6417 - accuracy: 0.5836
# Epoch 18: val_accuracy did not improve from 0.65964
# 9/9 [==============================] - 10s 1s/step - loss: 0.6417 - accuracy: 0.5836 - val_loss: 0.6298 - val_accuracy: 0.6295
# Epoch 19/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6370 - accuracy: 0.6318
# Epoch 19: val_accuracy did not improve from 0.65964
# 9/9 [==============================] - 10s 1s/step - loss: 0.6370 - accuracy: 0.6318 - val_loss: 0.6266 - val_accuracy: 0.6325
# Epoch 20/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6345 - accuracy: 0.6258
# Epoch 20: val_accuracy did not improve from 0.65964
# 9/9 [==============================] - 10s 1s/step - loss: 0.6345 - accuracy: 0.6258 - val_loss: 0.6264 - val_accuracy: 0.6325
# Epoch 21/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6332 - accuracy: 0.6303
# Epoch 21: val_accuracy did not improve from 0.65964
# 9/9 [==============================] - 10s 1s/step - loss: 0.6332 - accuracy: 0.6303 - val_loss: 0.6221 - val_accuracy: 0.6416
# Epoch 22/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6320 - accuracy: 0.6288
# Epoch 22: val_accuracy did not improve from 0.65964
# 9/9 [==============================] - 10s 1s/step - loss: 0.6320 - accuracy: 0.6288 - val_loss: 0.6222 - val_accuracy: 0.6355
# Epoch 23/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6282 - accuracy: 0.6363
# Epoch 23: val_accuracy improved from 0.65964 to 0.67169, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6282 - accuracy: 0.6363 - val_loss: 0.6181 - val_accuracy: 0.6717
# Epoch 24/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6253 - accuracy: 0.6340
# Epoch 24: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6253 - accuracy: 0.6340 - val_loss: 0.6276 - val_accuracy: 0.6325
# Epoch 25/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6247 - accuracy: 0.6386
# Epoch 25: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6247 - accuracy: 0.6386 - val_loss: 0.6304 - val_accuracy: 0.6325
# Epoch 26/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6275 - accuracy: 0.6370
# Epoch 26: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6275 - accuracy: 0.6370 - val_loss: 0.6185 - val_accuracy: 0.6416
# Epoch 27/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6230 - accuracy: 0.6468
# Epoch 27: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6230 - accuracy: 0.6468 - val_loss: 0.6297 - val_accuracy: 0.6355
# Epoch 28/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6239 - accuracy: 0.6340
# Epoch 28: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6239 - accuracy: 0.6340 - val_loss: 0.6127 - val_accuracy: 0.6295
# Epoch 29/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6162 - accuracy: 0.6453
# Epoch 29: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6162 - accuracy: 0.6453 - val_loss: 0.6202 - val_accuracy: 0.6446
# Epoch 30/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6205 - accuracy: 0.6438
# Epoch 30: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6205 - accuracy: 0.6438 - val_loss: 0.6177 - val_accuracy: 0.6416
# Epoch 31/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6149 - accuracy: 0.6498
# Epoch 31: val_accuracy did not improve from 0.67169
# 9/9 [==============================] - 10s 1s/step - loss: 0.6149 - accuracy: 0.6498 - val_loss: 0.6099 - val_accuracy: 0.6536
# Epoch 32/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6089 - accuracy: 0.6551
# Epoch 32: val_accuracy improved from 0.67169 to 0.67470, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6089 - accuracy: 0.6551 - val_loss: 0.6068 - val_accuracy: 0.6747
# Epoch 33/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6080 - accuracy: 0.6514
# Epoch 33: val_accuracy did not improve from 0.67470
# 9/9 [==============================] - 10s 1s/step - loss: 0.6080 - accuracy: 0.6514 - val_loss: 0.6074 - val_accuracy: 0.6747
# Epoch 34/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6075 - accuracy: 0.6581
# Epoch 34: val_accuracy improved from 0.67470 to 0.68072, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6075 - accuracy: 0.6581 - val_loss: 0.5996 - val_accuracy: 0.6807
# Epoch 35/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6018 - accuracy: 0.6566
# Epoch 35: val_accuracy did not improve from 0.68072
# 9/9 [==============================] - 10s 1s/step - loss: 0.6018 - accuracy: 0.6566 - val_loss: 0.6037 - val_accuracy: 0.6687
# Epoch 36/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6010 - accuracy: 0.6649
# Epoch 36: val_accuracy did not improve from 0.68072
# 9/9 [==============================] - 10s 1s/step - loss: 0.6010 - accuracy: 0.6649 - val_loss: 0.6011 - val_accuracy: 0.6687
# Epoch 37/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6086 - accuracy: 0.6453
# Epoch 37: val_accuracy did not improve from 0.68072
# 9/9 [==============================] - 11s 1s/step - loss: 0.6086 - accuracy: 0.6453 - val_loss: 0.6045 - val_accuracy: 0.6536
# Epoch 38/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6122 - accuracy: 0.6348
# Epoch 38: val_accuracy did not improve from 0.68072
# 9/9 [==============================] - 10s 1s/step - loss: 0.6122 - accuracy: 0.6348 - val_loss: 0.6120 - val_accuracy: 0.6506
# Epoch 39/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6036 - accuracy: 0.6536
# Epoch 39: val_accuracy did not improve from 0.68072
# 9/9 [==============================] - 10s 1s/step - loss: 0.6036 - accuracy: 0.6536 - val_loss: 0.5995 - val_accuracy: 0.6717
# Epoch 40/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6050 - accuracy: 0.6694
# Epoch 40: val_accuracy did not improve from 0.68072
# 9/9 [==============================] - 10s 1s/step - loss: 0.6050 - accuracy: 0.6694 - val_loss: 0.6002 - val_accuracy: 0.6536
# Epoch 41/100
# 9/9 [==============================] - ETA: 0s - loss: 0.5972 - accuracy: 0.6724
# Epoch 41: val_accuracy did not improve from 0.68072
# 9/9 [==============================] - 10s 1s/step - loss: 0.5972 - accuracy: 0.6724 - val_loss: 0.5962 - val_accuracy: 0.6747
# Epoch 42/100
# 9/9 [==============================] - ETA: 0s - loss: 0.5903 - accuracy: 0.6717
# Epoch 42: val_accuracy did not improve from 0.68072
# 9/9 [==============================] - 10s 1s/step - loss: 0.5903 - accuracy: 0.6717 - val_loss: 0.5972 - val_accuracy: 0.6687
# Epoch 43/100
# 9/9 [==============================] - ETA: 0s - loss: 0.5989 - accuracy: 0.6551
# Epoch 43: val_accuracy did not improve from 0.68072
# 9/9 [==============================] - 10s 1s/step - loss: 0.5989 - accuracy: 0.6551 - val_loss: 0.6384 - val_accuracy: 0.6145
# Epoch 44/100
# 9/9 [==============================] - ETA: 0s - loss: 0.5932 - accuracy: 0.6574
# Epoch 44: val_accuracy did not improve from 0.68072
# 9/9 [==============================] - 10s 1s/step - loss: 0.5932 - accuracy: 0.6574 - val_loss: 0.5969 - val_accuracy: 0.6687

# %%
best_model = load_model(model_path)
best_model.evaluate([X_test, features_test], y_data_test)
# Out:
# 13/13 [==============================] - 1s 64ms/step - loss: 0.6091 - accuracy: 0.6394
# [0.6090966463088989, 0.6394230723381042]

# %%
import matplotlib.pyplot as plt

y_acc = hist.history["val_accuracy"]
y_vloss = hist.history["val_loss"]
xs = np.arange(1, len(y_acc) + 1)

plt.figure(figsize = (12,8))
plt.plot(xs, y_acc, label = "Validation Accuracy")
plt.plot(xs, y_vloss, label = "Validation loss")
plt.legend(), plt.grid(), plt.xlabel("Epoch"), plt.title("functional First"), plt.ylim([0.4,1])
plt.show()

# %%
from sklearn.metrics import confusion_matrix
y_train_pred=best_model.predict([X_test, features_test])
yhat=[]
for data in y_train_pred:
  if data>=0.5:
    yhat.append(1)
  else:
    yhat.append(0)
yhat

# %%
cf = confusion_matrix(y_data_test, yhat)
print(cf)
# Out:
# [[134  50]
#  [100 132]]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
p = precision_score(y_data_test, yhat)
print(p)
r = recall_score(y_data_test, yhat)
print(r)
f1 = f1_score(y_data_test, yhat)
print(f1)
# Out:
# 0.7252747252747253
# 0.5689655172413793
# 0.6376811594202899

# %% [markdown]
# # train_test dataset에 없는 다른 데이터로 모델 테스트

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/test/fffff.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data_other=np.array(result)
result_data_other.shape
# Out:
# (520, 30, 901)

# %%
features_other = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/test/test_df_15세65세_aug전.csv")
features_other = features_other.iloc[:,[4,5,6,7]]
features_other
# Out:
#      man  respiratory_condition  fever_muscle_pain  COVID-19
# 0      1                      1                  0         0
# 1      1                      1                  0         0
# 2      1                      0                  0         0
# 3      1                      0                  0         0
# 4      1                      0                  0         0
# ..   ...                    ...                ...       ...
# 515    0                      0                  1         1
# 516    0                      0                  0         1
# 517    0                      0                  0         1
# 518    0                      0                  1         1
# 519    0                      0                  1         1
#
# [520 rows x 4 columns]

# %%
feature_test_data = features_other.iloc[:,:-1].values
y_test_data = features_other.iloc[:,-1].values

# %%
y_train_pred=model.predict([result_data_other, feature_test_data])
yhat_test=[]
for data in y_train_pred:
  if data>=0.5:
    yhat_test.append(1)
  else:
    yhat_test.append(0)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
p = precision_score(y_test_data, yhat_test)
print(p)
r = recall_score(y_test_data, yhat_test)
print(r)
f1 = f1_score(y_test_data, yhat_test)
print(f1)
# Out:
# 0.5188916876574308
# 0.7923076923076923
# 0.6270928462709284

# %%
model.evaluate([result_data_other, feature_test_data], y_test_data)
# Out:
# 17/17 [==============================] - 1s 61ms/step - loss: 0.7484 - accuracy: 0.5288
# [0.7483586668968201, 0.5288461446762085]
