# %%
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.12)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, Concatenate, GlobalAveragePooling2D
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import pickle5 as pickle
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf
seed=2022
tf.random.set_seed(seed)
np.random.seed(seed)

# %% [markdown]
# # mfcc

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/mfcc/mfcc_lst_test.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data=np.array(result)
result_data.shape
# Out:
# (2076, 30, 901)

# %% [markdown]
# # codiv-19, feature

# %%
y = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/mfcc/Y_data_test.csv").iloc[:,0].values

# %%
features = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/csv파일/df_1565_test2.csv")
features = features.iloc[:,[4,5,6,7]]
feature_lst = []
for i in features.index:
    for _ in range(4):
        feature_lst.append(features.iloc[i,:].values)
features = pd.DataFrame(feature_lst)
features.shape
# Out:
# (2076, 4)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    result_data, features, stratify = features, test_size = 0.2
)

# %%
features_train = Y_train.iloc[:,:-1].values
y_data_train = Y_train.iloc[:,-1].values

# %%
features_test = Y_test.iloc[:,:-1].values
y_data_test = Y_test.iloc[:,-1].values

# %%
# 각 입력에 대한 형태를 명시
img_input = Input(shape = (30,901,1), name = "features_train")
form_input = Input(shape = (3,), name = "y_data_train")

# %%
# 이미지 입력
x_1 = Conv2D(32, (3,3), activation = "relu")(img_input)
x_1 = Conv2D(32, (3,3), activation = "relu")(x_1)
x_1 = MaxPooling2D(strides = 2)(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = Conv2D(16, (3,3), activation='relu')(x_1)
x_1 = Conv2D(16, (3,3), activation='relu')(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = GlobalAveragePooling2D()(x_1)
x_1 = Flatten()(x_1)

# 피쳐 입력
# x_2 = Dense(128, input_dim = 3 ,activation  = "relu")(form_input)
x_2 = Dense(8, activation = "relu")(form_input)

x = Concatenate()([x_1, x_2])
rate_pred = Dense(1, name = "covid", activation = "sigmoid")(x)

# %%
model = Model(inputs = [img_input, form_input],
              outputs = [rate_pred])

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  features_train (InputLayer)    [(None, 30, 901, 1)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 28, 899, 32)  320         ['features_train[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 26, 897, 32)  9248        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 13, 448, 32)  0           ['conv2d_1[0][0]']
#
#  dropout (Dropout)              (None, 13, 448, 32)  0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 11, 446, 16)  4624        ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 9, 444, 16)   2320        ['conv2d_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 9, 444, 16)   0           ['conv2d_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 16)          0           ['dropout_1[0][0]']
#  alAveragePooling2D)
#
#  y_data_train (InputLayer)      [(None, 3)]          0           []
#
#  flatten (Flatten)              (None, 16)           0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 8)            32          ['y_data_train[0][0]']
#
#  concatenate (Concatenate)      (None, 24)           0           ['flatten[0][0]',
#                                                                   'dense[0][0]']
#
#  covid (Dense)                  (None, 1)            25          ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 16,569
# Trainable params: 16,569
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Nadam
nadam = Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

# %%
model.compile(optimizer = nadam,
              loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
model_path = "functional-first.h5"
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1, monitor = "val_accuracy")
es = EarlyStopping(patience=10, monitor = "val_accuracy")

# %%
hist = model.fit([X_train, features_train] , y_data_train,
                 epochs = 100, batch_size = 200,
                 validation_split=0.2, callbacks = [es, mc])
# Out:
# Epoch 1/100
# 7/7 [==============================] - ETA: 0s - loss: 0.7295 - accuracy: 0.5008
# Epoch 1: val_accuracy improved from -inf to 0.48795, saving model to functional-first.h5
# 7/7 [==============================] - 12s 746ms/step - loss: 0.7295 - accuracy: 0.5008 - val_loss: 0.7143 - val_accuracy: 0.4880
# Epoch 2/100
# 7/7 [==============================] - ETA: 0s - loss: 0.7078 - accuracy: 0.5038
# Epoch 2: val_accuracy improved from 0.48795 to 0.51807, saving model to functional-first.h5
# 7/7 [==============================] - 2s 292ms/step - loss: 0.7078 - accuracy: 0.5038 - val_loss: 0.7001 - val_accuracy: 0.5181
# Epoch 3/100
# 7/7 [==============================] - ETA: 0s - loss: 0.7046 - accuracy: 0.5045
# Epoch 3: val_accuracy improved from 0.51807 to 0.53614, saving model to functional-first.h5
# 7/7 [==============================] - 2s 286ms/step - loss: 0.7046 - accuracy: 0.5045 - val_loss: 0.7012 - val_accuracy: 0.5361
# Epoch 4/100
# 7/7 [==============================] - ETA: 0s - loss: 0.7015 - accuracy: 0.5211
# Epoch 4: val_accuracy improved from 0.53614 to 0.56928, saving model to functional-first.h5
# 7/7 [==============================] - 2s 272ms/step - loss: 0.7015 - accuracy: 0.5211 - val_loss: 0.7021 - val_accuracy: 0.5693
# Epoch 5/100
# 7/7 [==============================] - ETA: 0s - loss: 0.7051 - accuracy: 0.5136
# Epoch 5: val_accuracy did not improve from 0.56928
# 7/7 [==============================] - 2s 272ms/step - loss: 0.7051 - accuracy: 0.5136 - val_loss: 0.6924 - val_accuracy: 0.5602
# Epoch 6/100
# 7/7 [==============================] - ETA: 0s - loss: 0.7017 - accuracy: 0.5188
# Epoch 6: val_accuracy did not improve from 0.56928
# 7/7 [==============================] - 2s 257ms/step - loss: 0.7017 - accuracy: 0.5188 - val_loss: 0.6907 - val_accuracy: 0.5633
# Epoch 7/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6980 - accuracy: 0.5264
# Epoch 7: val_accuracy did not improve from 0.56928
# 7/7 [==============================] - 2s 255ms/step - loss: 0.6980 - accuracy: 0.5264 - val_loss: 0.6900 - val_accuracy: 0.5512
# Epoch 8/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6997 - accuracy: 0.5211
# Epoch 8: val_accuracy did not improve from 0.56928
# 7/7 [==============================] - 2s 254ms/step - loss: 0.6997 - accuracy: 0.5211 - val_loss: 0.6901 - val_accuracy: 0.5392
# Epoch 9/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6949 - accuracy: 0.5188
# Epoch 9: val_accuracy did not improve from 0.56928
# 7/7 [==============================] - 2s 253ms/step - loss: 0.6949 - accuracy: 0.5188 - val_loss: 0.6874 - val_accuracy: 0.5693
# Epoch 10/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6951 - accuracy: 0.5346
# Epoch 10: val_accuracy did not improve from 0.56928
# 7/7 [==============================] - 2s 253ms/step - loss: 0.6951 - accuracy: 0.5346 - val_loss: 0.7017 - val_accuracy: 0.4970
# Epoch 11/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.5158
# Epoch 11: val_accuracy did not improve from 0.56928
# 7/7 [==============================] - 2s 253ms/step - loss: 0.6937 - accuracy: 0.5158 - val_loss: 0.6852 - val_accuracy: 0.5512
# Epoch 12/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6919 - accuracy: 0.5452
# Epoch 12: val_accuracy improved from 0.56928 to 0.57530, saving model to functional-first.h5
# 7/7 [==============================] - 2s 261ms/step - loss: 0.6919 - accuracy: 0.5452 - val_loss: 0.6834 - val_accuracy: 0.5753
# Epoch 13/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6896 - accuracy: 0.5452
# Epoch 13: val_accuracy did not improve from 0.57530
# 7/7 [==============================] - 2s 253ms/step - loss: 0.6896 - accuracy: 0.5452 - val_loss: 0.6989 - val_accuracy: 0.5000
# Epoch 14/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6917 - accuracy: 0.5346
# Epoch 14: val_accuracy did not improve from 0.57530
# 7/7 [==============================] - 2s 253ms/step - loss: 0.6917 - accuracy: 0.5346 - val_loss: 0.6829 - val_accuracy: 0.5452
# Epoch 15/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6891 - accuracy: 0.5429
# Epoch 15: val_accuracy did not improve from 0.57530
# 7/7 [==============================] - 2s 251ms/step - loss: 0.6891 - accuracy: 0.5429 - val_loss: 0.6810 - val_accuracy: 0.5663
# Epoch 16/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6878 - accuracy: 0.5459
# Epoch 16: val_accuracy improved from 0.57530 to 0.59036, saving model to functional-first.h5
# 7/7 [==============================] - 2s 258ms/step - loss: 0.6878 - accuracy: 0.5459 - val_loss: 0.6823 - val_accuracy: 0.5904
# Epoch 17/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6854 - accuracy: 0.5459
# Epoch 17: val_accuracy did not improve from 0.59036
# 7/7 [==============================] - 2s 252ms/step - loss: 0.6854 - accuracy: 0.5459 - val_loss: 0.6774 - val_accuracy: 0.5873
# Epoch 18/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6837 - accuracy: 0.5580
# Epoch 18: val_accuracy improved from 0.59036 to 0.59639, saving model to functional-first.h5
# 7/7 [==============================] - 2s 257ms/step - loss: 0.6837 - accuracy: 0.5580 - val_loss: 0.6781 - val_accuracy: 0.5964
# Epoch 19/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6852 - accuracy: 0.5407
# Epoch 19: val_accuracy did not improve from 0.59639
# 7/7 [==============================] - 2s 252ms/step - loss: 0.6852 - accuracy: 0.5407 - val_loss: 0.6755 - val_accuracy: 0.5753
# Epoch 20/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6817 - accuracy: 0.5617
# Epoch 20: val_accuracy did not improve from 0.59639
# 7/7 [==============================] - 2s 249ms/step - loss: 0.6817 - accuracy: 0.5617 - val_loss: 0.6806 - val_accuracy: 0.5663
# Epoch 21/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6819 - accuracy: 0.5791
# Epoch 21: val_accuracy did not improve from 0.59639
# 7/7 [==============================] - 2s 249ms/step - loss: 0.6819 - accuracy: 0.5791 - val_loss: 0.6726 - val_accuracy: 0.5873
# Epoch 22/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6804 - accuracy: 0.5595
# Epoch 22: val_accuracy did not improve from 0.59639
# 7/7 [==============================] - 2s 248ms/step - loss: 0.6804 - accuracy: 0.5595 - val_loss: 0.6728 - val_accuracy: 0.5934
# Epoch 23/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6781 - accuracy: 0.5873
# Epoch 23: val_accuracy did not improve from 0.59639
# 7/7 [==============================] - 2s 248ms/step - loss: 0.6781 - accuracy: 0.5873 - val_loss: 0.6701 - val_accuracy: 0.5904
# Epoch 24/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6765 - accuracy: 0.5610
# Epoch 24: val_accuracy did not improve from 0.59639
# 7/7 [==============================] - 2s 247ms/step - loss: 0.6765 - accuracy: 0.5610 - val_loss: 0.6810 - val_accuracy: 0.5572
# Epoch 25/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6769 - accuracy: 0.5715
# Epoch 25: val_accuracy improved from 0.59639 to 0.62349, saving model to functional-first.h5
# 7/7 [==============================] - 2s 254ms/step - loss: 0.6769 - accuracy: 0.5715 - val_loss: 0.6699 - val_accuracy: 0.6235
# Epoch 26/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6777 - accuracy: 0.5738
# Epoch 26: val_accuracy did not improve from 0.62349
# 7/7 [==============================] - 2s 248ms/step - loss: 0.6777 - accuracy: 0.5738 - val_loss: 0.6691 - val_accuracy: 0.5783
# Epoch 27/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6747 - accuracy: 0.5648
# Epoch 27: val_accuracy did not improve from 0.62349
# 7/7 [==============================] - 2s 248ms/step - loss: 0.6747 - accuracy: 0.5648 - val_loss: 0.6847 - val_accuracy: 0.5422
# Epoch 28/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6738 - accuracy: 0.5873
# Epoch 28: val_accuracy did not improve from 0.62349
# 7/7 [==============================] - 2s 244ms/step - loss: 0.6738 - accuracy: 0.5873 - val_loss: 0.6681 - val_accuracy: 0.6145
# Epoch 29/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6695 - accuracy: 0.5768
# Epoch 29: val_accuracy did not improve from 0.62349
# 7/7 [==============================] - 2s 247ms/step - loss: 0.6695 - accuracy: 0.5768 - val_loss: 0.6765 - val_accuracy: 0.5813
# Epoch 30/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6726 - accuracy: 0.5806
# Epoch 30: val_accuracy did not improve from 0.62349
# 7/7 [==============================] - 2s 247ms/step - loss: 0.6726 - accuracy: 0.5806 - val_loss: 0.6669 - val_accuracy: 0.6084
# Epoch 31/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6663 - accuracy: 0.5926
# Epoch 31: val_accuracy did not improve from 0.62349
# 7/7 [==============================] - 2s 247ms/step - loss: 0.6663 - accuracy: 0.5926 - val_loss: 0.6717 - val_accuracy: 0.5813
# Epoch 32/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6671 - accuracy: 0.5828
# Epoch 32: val_accuracy did not improve from 0.62349
# 7/7 [==============================] - 2s 244ms/step - loss: 0.6671 - accuracy: 0.5828 - val_loss: 0.6609 - val_accuracy: 0.6205
# Epoch 33/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6856 - accuracy: 0.5550
# Epoch 33: val_accuracy improved from 0.62349 to 0.65060, saving model to functional-first.h5
# 7/7 [==============================] - 2s 253ms/step - loss: 0.6856 - accuracy: 0.5550 - val_loss: 0.6604 - val_accuracy: 0.6506
# Epoch 34/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6660 - accuracy: 0.5889
# Epoch 34: val_accuracy did not improve from 0.65060
# 7/7 [==============================] - 2s 246ms/step - loss: 0.6660 - accuracy: 0.5889 - val_loss: 0.6651 - val_accuracy: 0.5843
# Epoch 35/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6656 - accuracy: 0.5798
# Epoch 35: val_accuracy did not improve from 0.65060
# 7/7 [==============================] - 2s 245ms/step - loss: 0.6656 - accuracy: 0.5798 - val_loss: 0.6628 - val_accuracy: 0.6024
# Epoch 36/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6639 - accuracy: 0.5873
# Epoch 36: val_accuracy did not improve from 0.65060
# 7/7 [==============================] - 2s 246ms/step - loss: 0.6639 - accuracy: 0.5873 - val_loss: 0.6575 - val_accuracy: 0.6295
# Epoch 37/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6616 - accuracy: 0.5956
# Epoch 37: val_accuracy did not improve from 0.65060
# 7/7 [==============================] - 2s 245ms/step - loss: 0.6616 - accuracy: 0.5956 - val_loss: 0.6645 - val_accuracy: 0.5904
# Epoch 38/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6595 - accuracy: 0.6002
# Epoch 38: val_accuracy did not improve from 0.65060
# 7/7 [==============================] - 2s 245ms/step - loss: 0.6595 - accuracy: 0.6002 - val_loss: 0.6545 - val_accuracy: 0.6295
# Epoch 39/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6581 - accuracy: 0.5926
# Epoch 39: val_accuracy did not improve from 0.65060
# 7/7 [==============================] - 2s 246ms/step - loss: 0.6581 - accuracy: 0.5926 - val_loss: 0.6592 - val_accuracy: 0.6205
# Epoch 40/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6534 - accuracy: 0.6092
# Epoch 40: val_accuracy did not improve from 0.65060
# 7/7 [==============================] - 2s 246ms/step - loss: 0.6534 - accuracy: 0.6092 - val_loss: 0.6999 - val_accuracy: 0.5602
# Epoch 41/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6594 - accuracy: 0.5911
# Epoch 41: val_accuracy did not improve from 0.65060
# 7/7 [==============================] - 2s 247ms/step - loss: 0.6594 - accuracy: 0.5911 - val_loss: 0.7054 - val_accuracy: 0.5151
# Epoch 42/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6552 - accuracy: 0.6024
# Epoch 42: val_accuracy did not improve from 0.65060
# 7/7 [==============================] - 2s 247ms/step - loss: 0.6552 - accuracy: 0.6024 - val_loss: 0.6490 - val_accuracy: 0.5994
# Epoch 43/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6513 - accuracy: 0.6122
# Epoch 43: val_accuracy did not improve from 0.65060
# 7/7 [==============================] - 2s 247ms/step - loss: 0.6513 - accuracy: 0.6122 - val_loss: 0.6460 - val_accuracy: 0.6205

# %%
best_model = load_model(model_path)
best_model.evaluate([X_test, features_test], y_data_test)
# Out:
# 13/13 [==============================] - 1s 13ms/step - loss: 0.6595 - accuracy: 0.6058
# [0.6594696640968323, 0.6057692170143127]

# %%
import matplotlib.pyplot as plt

y_acc = hist.history["val_accuracy"]
y_vloss = hist.history["val_loss"]
xs = np.arange(1, len(y_acc) + 1)

plt.figure(figsize = (12,8))
plt.plot(xs, y_acc, label = "Validation Accuracy")
plt.plot(xs, y_vloss, label = "Validation loss")
plt.legend(), plt.grid(), plt.xlabel("Epoch"), plt.title("functional First"), plt.ylim([0.4,1])
plt.show()

# %%
from sklearn.metrics import confusion_matrix
y_train_pred=best_model.predict([X_test, features_test])
yhat=[]
for data in y_train_pred:
  if data>=0.5:
    yhat.append(1)
  else:
    yhat.append(0)
yhat

# %%
cf = confusion_matrix(y_data_test, yhat)
print(cf)
# Out:
# [[ 59 125]
#  [ 39 193]]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
p = precision_score(y_data_test, yhat)
print(p)
r = recall_score(y_data_test, yhat)
print(r)
f1 = f1_score(y_data_test, yhat)
print(f1)
# Out:
# 0.6069182389937107
# 0.8318965517241379
# 0.7018181818181818

# %% [markdown]
# # train_test dataset에 없는 다른 데이터로 모델 테스트

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/test/test_mfcc_15세65세_aug전.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data_other=np.array(result)
result_data_other.shape
# Out:
# (520, 30, 901)

# %%
features_other = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/test/test_df_15세65세_aug전.csv")
features_other = features_other.iloc[:,[4,5,6,7]]
features_other
# Out:
#      man  respiratory_condition  fever_muscle_pain  COVID-19
# 0      1                      1                  0         0
# 1      1                      1                  0         0
# 2      1                      0                  0         0
# 3      1                      0                  0         0
# 4      1                      0                  0         0
# ..   ...                    ...                ...       ...
# 515    0                      0                  1         1
# 516    0                      0                  0         1
# 517    0                      0                  0         1
# 518    0                      0                  1         1
# 519    0                      0                  1         1
#
# [520 rows x 4 columns]

# %%
feature_test_data = features_other.iloc[:,:-1].values
y_test_data = features_other.iloc[:,-1].values

# %%
y_train_pred=model.predict([result_data_other, feature_test_data])
yhat_test=[]
for data in y_train_pred:
  if data>=0.5:
    yhat_test.append(1)
  else:
    yhat_test.append(0)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
p = precision_score(y_test_data, yhat_test)
print(p)
r = recall_score(y_test_data, yhat_test)
print(r)
f1 = f1_score(y_test_data, yhat_test)
print(f1)
# Out:
# 0.5121951219512195
# 0.8884615384615384
# 0.649789029535865

# %%
model.evaluate([result_data_other, feature_test_data], y_test_data)
# Out:
# 17/17 [==============================] - 0s 13ms/step - loss: 0.7042 - accuracy: 0.5212
# [0.704157292842865, 0.5211538672447205]
