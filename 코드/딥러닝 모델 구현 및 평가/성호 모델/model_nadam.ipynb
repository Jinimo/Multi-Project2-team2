# %%
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.12)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, Concatenate, GlobalAveragePooling2D
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import pickle5 as pickle
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf
seed=2022
tf.random.set_seed(seed)
np.random.seed(seed)

# %% [markdown]
# # mfcc

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/mfcc/mfcc_lst_test.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data=np.array(result)
result_data.shape
# Out:
# (2076, 30, 901)

# %% [markdown]
# # codiv-19, feature

# %%
y = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/mfcc/Y_data_test.csv").iloc[:,0].values

# %%
features = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/csv파일/df_1565_test2.csv")
features = features.iloc[:,[4,5,6,7]]
feature_lst = []
for i in features.index:
    for _ in range(4):
        feature_lst.append(features.iloc[i,:].values)
features = pd.DataFrame(feature_lst)
features.shape
# Out:
# (2076, 4)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    result_data, features, stratify = features, test_size = 0.2
)

# %%
features_train = Y_train.iloc[:,:-1].values
y_data_train = Y_train.iloc[:,-1].values

# %%
features_test = Y_test.iloc[:,:-1].values
y_data_test = Y_test.iloc[:,-1].values

# %%
# 각 입력에 대한 형태를 명시
img_input = Input(shape = (30,901,1), name = "features_train")
form_input = Input(shape = (3,), name = "y_data_train")

# %%
# 이미지 입력
x_1 = Conv2D(64, (3,3), activation = "relu")(img_input)
x_1 = Conv2D(64, (3,3), activation = "relu")(x_1)
x_1 = MaxPooling2D(strides = 2)(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = Conv2D(32, (3,3), activation='relu')(x_1)
x_1 = Conv2D(32, (3,3), activation='relu')(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = GlobalAveragePooling2D()(x_1)

# 피쳐 입력
# x_2 = Dense(128, input_dim = 3 ,activation  = "relu")(form_input)
x_2 = Dense(16, activation = "relu")(form_input)

x = Concatenate()([x_1, x_2])
rate_pred = Dense(1, name = "covid", activation = "sigmoid")(x)

# %%
model = Model(inputs = [img_input, form_input],
              outputs = [rate_pred])

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  features_train (InputLayer)    [(None, 30, 901, 1)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 28, 899, 64)  640         ['features_train[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 26, 897, 64)  36928       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 13, 448, 64)  0           ['conv2d_1[0][0]']
#
#  dropout (Dropout)              (None, 13, 448, 64)  0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 11, 446, 32)  18464       ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 9, 444, 32)   9248        ['conv2d_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 9, 444, 32)   0           ['conv2d_3[0][0]']
#
#  y_data_train (InputLayer)      [(None, 3)]          0           []
#
#  global_average_pooling2d (Glob  (None, 32)          0           ['dropout_1[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 16)           64          ['y_data_train[0][0]']
#
#  concatenate (Concatenate)      (None, 48)           0           ['global_average_pooling2d[0][0]'
#                                                                  , 'dense[0][0]']
#
#  covid (Dense)                  (None, 1)            49          ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 65,393
# Trainable params: 65,393
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Nadam
nadam = Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

# %%
model.compile(optimizer = nadam,
              loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
model_path = "functional-first.h5"
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1, monitor = "val_accuracy")
es = EarlyStopping(patience=10, monitor = "val_accuracy")

# %%
hist = model.fit([X_train, features_train] , y_data_train,
                 epochs = 100, batch_size = 200,
                 validation_split=0.2, callbacks = [es, mc])
# Out:
# Epoch 1/100
# 7/7 [==============================] - ETA: 0s - loss: 0.7460 - accuracy: 0.5008
# Epoch 1: val_accuracy improved from -inf to 0.55723, saving model to functional-first.h5
# 7/7 [==============================] - 23s 2s/step - loss: 0.7460 - accuracy: 0.5008 - val_loss: 0.6888 - val_accuracy: 0.5572
# Epoch 2/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6955 - accuracy: 0.5346
# Epoch 2: val_accuracy improved from 0.55723 to 0.56024, saving model to functional-first.h5
# 7/7 [==============================] - 4s 596ms/step - loss: 0.6955 - accuracy: 0.5346 - val_loss: 0.6859 - val_accuracy: 0.5602
# Epoch 3/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6912 - accuracy: 0.5429
# Epoch 3: val_accuracy improved from 0.56024 to 0.57530, saving model to functional-first.h5
# 7/7 [==============================] - 4s 573ms/step - loss: 0.6912 - accuracy: 0.5429 - val_loss: 0.6841 - val_accuracy: 0.5753
# Epoch 4/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6874 - accuracy: 0.5316
# Epoch 4: val_accuracy did not improve from 0.57530
# 7/7 [==============================] - 4s 565ms/step - loss: 0.6874 - accuracy: 0.5316 - val_loss: 0.6887 - val_accuracy: 0.5633
# Epoch 5/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6883 - accuracy: 0.5384
# Epoch 5: val_accuracy did not improve from 0.57530
# 7/7 [==============================] - 4s 566ms/step - loss: 0.6883 - accuracy: 0.5384 - val_loss: 0.6772 - val_accuracy: 0.5633
# Epoch 6/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6842 - accuracy: 0.5550
# Epoch 6: val_accuracy did not improve from 0.57530
# 7/7 [==============================] - 4s 567ms/step - loss: 0.6842 - accuracy: 0.5550 - val_loss: 0.6744 - val_accuracy: 0.5723
# Epoch 7/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6802 - accuracy: 0.5452
# Epoch 7: val_accuracy improved from 0.57530 to 0.58133, saving model to functional-first.h5
# 7/7 [==============================] - 4s 574ms/step - loss: 0.6802 - accuracy: 0.5452 - val_loss: 0.6716 - val_accuracy: 0.5813
# Epoch 8/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6802 - accuracy: 0.5377
# Epoch 8: val_accuracy did not improve from 0.58133
# 7/7 [==============================] - 4s 569ms/step - loss: 0.6802 - accuracy: 0.5377 - val_loss: 0.6698 - val_accuracy: 0.5783
# Epoch 9/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6747 - accuracy: 0.5535
# Epoch 9: val_accuracy did not improve from 0.58133
# 7/7 [==============================] - 4s 571ms/step - loss: 0.6747 - accuracy: 0.5535 - val_loss: 0.6695 - val_accuracy: 0.5663
# Epoch 10/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6733 - accuracy: 0.5474
# Epoch 10: val_accuracy improved from 0.58133 to 0.58434, saving model to functional-first.h5
# 7/7 [==============================] - 4s 578ms/step - loss: 0.6733 - accuracy: 0.5474 - val_loss: 0.6715 - val_accuracy: 0.5843
# Epoch 11/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6710 - accuracy: 0.5723
# Epoch 11: val_accuracy did not improve from 0.58434
# 7/7 [==============================] - 4s 572ms/step - loss: 0.6710 - accuracy: 0.5723 - val_loss: 0.6613 - val_accuracy: 0.5783
# Epoch 12/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6687 - accuracy: 0.5580
# Epoch 12: val_accuracy did not improve from 0.58434
# 7/7 [==============================] - 4s 573ms/step - loss: 0.6687 - accuracy: 0.5580 - val_loss: 0.6589 - val_accuracy: 0.5783
# Epoch 13/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6659 - accuracy: 0.5520
# Epoch 13: val_accuracy improved from 0.58434 to 0.59639, saving model to functional-first.h5
# 7/7 [==============================] - 4s 580ms/step - loss: 0.6659 - accuracy: 0.5520 - val_loss: 0.6656 - val_accuracy: 0.5964
# Epoch 14/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6656 - accuracy: 0.5730
# Epoch 14: val_accuracy did not improve from 0.59639
# 7/7 [==============================] - 4s 575ms/step - loss: 0.6656 - accuracy: 0.5730 - val_loss: 0.6540 - val_accuracy: 0.5693
# Epoch 15/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6615 - accuracy: 0.5708
# Epoch 15: val_accuracy did not improve from 0.59639
# 7/7 [==============================] - 4s 577ms/step - loss: 0.6615 - accuracy: 0.5708 - val_loss: 0.6516 - val_accuracy: 0.5633
# Epoch 16/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6591 - accuracy: 0.5655
# Epoch 16: val_accuracy improved from 0.59639 to 0.63855, saving model to functional-first.h5
# 7/7 [==============================] - 4s 582ms/step - loss: 0.6591 - accuracy: 0.5655 - val_loss: 0.6502 - val_accuracy: 0.6386
# Epoch 17/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6563 - accuracy: 0.5934
# Epoch 17: val_accuracy did not improve from 0.63855
# 7/7 [==============================] - 4s 579ms/step - loss: 0.6563 - accuracy: 0.5934 - val_loss: 0.6467 - val_accuracy: 0.5873
# Epoch 18/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6517 - accuracy: 0.5866
# Epoch 18: val_accuracy did not improve from 0.63855
# 7/7 [==============================] - 4s 577ms/step - loss: 0.6517 - accuracy: 0.5866 - val_loss: 0.6447 - val_accuracy: 0.6205
# Epoch 19/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6546 - accuracy: 0.5919
# Epoch 19: val_accuracy did not improve from 0.63855
# 7/7 [==============================] - 4s 581ms/step - loss: 0.6546 - accuracy: 0.5919 - val_loss: 0.6431 - val_accuracy: 0.5843
# Epoch 20/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6501 - accuracy: 0.5655
# Epoch 20: val_accuracy did not improve from 0.63855
# 7/7 [==============================] - 4s 583ms/step - loss: 0.6501 - accuracy: 0.5655 - val_loss: 0.6459 - val_accuracy: 0.5994
# Epoch 21/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6508 - accuracy: 0.5979
# Epoch 21: val_accuracy did not improve from 0.63855
# 7/7 [==============================] - 4s 578ms/step - loss: 0.6508 - accuracy: 0.5979 - val_loss: 0.6394 - val_accuracy: 0.5783
# Epoch 22/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6467 - accuracy: 0.5851
# Epoch 22: val_accuracy did not improve from 0.63855
# 7/7 [==============================] - 4s 580ms/step - loss: 0.6467 - accuracy: 0.5851 - val_loss: 0.6375 - val_accuracy: 0.6325
# Epoch 23/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6438 - accuracy: 0.5949
# Epoch 23: val_accuracy did not improve from 0.63855
# 7/7 [==============================] - 4s 582ms/step - loss: 0.6438 - accuracy: 0.5949 - val_loss: 0.6347 - val_accuracy: 0.6325
# Epoch 24/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6408 - accuracy: 0.6130
# Epoch 24: val_accuracy improved from 0.63855 to 0.64458, saving model to functional-first.h5
# 7/7 [==============================] - 4s 598ms/step - loss: 0.6408 - accuracy: 0.6130 - val_loss: 0.6390 - val_accuracy: 0.6446
# Epoch 25/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6389 - accuracy: 0.6039
# Epoch 25: val_accuracy did not improve from 0.64458
# 7/7 [==============================] - 4s 583ms/step - loss: 0.6389 - accuracy: 0.6039 - val_loss: 0.6304 - val_accuracy: 0.6265
# Epoch 26/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6447 - accuracy: 0.5911
# Epoch 26: val_accuracy did not improve from 0.64458
# 7/7 [==============================] - 4s 581ms/step - loss: 0.6447 - accuracy: 0.5911 - val_loss: 0.6306 - val_accuracy: 0.6175
# Epoch 27/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6355 - accuracy: 0.6092
# Epoch 27: val_accuracy did not improve from 0.64458
# 7/7 [==============================] - 4s 603ms/step - loss: 0.6355 - accuracy: 0.6092 - val_loss: 0.6516 - val_accuracy: 0.6235
# Epoch 28/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6396 - accuracy: 0.6114
# Epoch 28: val_accuracy did not improve from 0.64458
# 7/7 [==============================] - 4s 583ms/step - loss: 0.6396 - accuracy: 0.6114 - val_loss: 0.6284 - val_accuracy: 0.6355
# Epoch 29/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6303 - accuracy: 0.6130
# Epoch 29: val_accuracy did not improve from 0.64458
# 7/7 [==============================] - 4s 584ms/step - loss: 0.6303 - accuracy: 0.6130 - val_loss: 0.6447 - val_accuracy: 0.6235
# Epoch 30/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6428 - accuracy: 0.6017
# Epoch 30: val_accuracy improved from 0.64458 to 0.65060, saving model to functional-first.h5
# 7/7 [==============================] - 4s 590ms/step - loss: 0.6428 - accuracy: 0.6017 - val_loss: 0.6293 - val_accuracy: 0.6506
# Epoch 31/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6285 - accuracy: 0.6325
# Epoch 31: val_accuracy did not improve from 0.65060
# 7/7 [==============================] - 4s 586ms/step - loss: 0.6285 - accuracy: 0.6325 - val_loss: 0.6312 - val_accuracy: 0.6446
# Epoch 32/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6272 - accuracy: 0.6258
# Epoch 32: val_accuracy improved from 0.65060 to 0.65663, saving model to functional-first.h5
# 7/7 [==============================] - 4s 592ms/step - loss: 0.6272 - accuracy: 0.6258 - val_loss: 0.6207 - val_accuracy: 0.6566
# Epoch 33/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6357 - accuracy: 0.6024
# Epoch 33: val_accuracy did not improve from 0.65663
# 7/7 [==============================] - 4s 587ms/step - loss: 0.6357 - accuracy: 0.6024 - val_loss: 0.6231 - val_accuracy: 0.6416
# Epoch 34/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6236 - accuracy: 0.6318
# Epoch 34: val_accuracy did not improve from 0.65663
# 7/7 [==============================] - 4s 584ms/step - loss: 0.6236 - accuracy: 0.6318 - val_loss: 0.6276 - val_accuracy: 0.6325
# Epoch 35/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6241 - accuracy: 0.6227
# Epoch 35: val_accuracy did not improve from 0.65663
# 7/7 [==============================] - 4s 586ms/step - loss: 0.6241 - accuracy: 0.6227 - val_loss: 0.6420 - val_accuracy: 0.6325
# Epoch 36/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6220 - accuracy: 0.6446
# Epoch 36: val_accuracy improved from 0.65663 to 0.66566, saving model to functional-first.h5
# 7/7 [==============================] - 4s 594ms/step - loss: 0.6220 - accuracy: 0.6446 - val_loss: 0.6148 - val_accuracy: 0.6657
# Epoch 37/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6168 - accuracy: 0.6423
# Epoch 37: val_accuracy did not improve from 0.66566
# 7/7 [==============================] - 4s 588ms/step - loss: 0.6168 - accuracy: 0.6423 - val_loss: 0.6365 - val_accuracy: 0.6205
# Epoch 38/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6167 - accuracy: 0.6446
# Epoch 38: val_accuracy did not improve from 0.66566
# 7/7 [==============================] - 4s 587ms/step - loss: 0.6167 - accuracy: 0.6446 - val_loss: 0.6234 - val_accuracy: 0.6446
# Epoch 39/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6177 - accuracy: 0.6491
# Epoch 39: val_accuracy did not improve from 0.66566
# 7/7 [==============================] - 4s 587ms/step - loss: 0.6177 - accuracy: 0.6491 - val_loss: 0.6201 - val_accuracy: 0.6506
# Epoch 40/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6096 - accuracy: 0.6596
# Epoch 40: val_accuracy did not improve from 0.66566
# 7/7 [==============================] - 4s 590ms/step - loss: 0.6096 - accuracy: 0.6596 - val_loss: 0.6420 - val_accuracy: 0.6235
# Epoch 41/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6061 - accuracy: 0.6536
# Epoch 41: val_accuracy did not improve from 0.66566
# 7/7 [==============================] - 4s 589ms/step - loss: 0.6061 - accuracy: 0.6536 - val_loss: 0.6689 - val_accuracy: 0.5994
# Epoch 42/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6134 - accuracy: 0.6416
# Epoch 42: val_accuracy improved from 0.66566 to 0.68072, saving model to functional-first.h5
# 7/7 [==============================] - 4s 595ms/step - loss: 0.6134 - accuracy: 0.6416 - val_loss: 0.6084 - val_accuracy: 0.6807
# Epoch 43/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6038 - accuracy: 0.6529
# Epoch 43: val_accuracy did not improve from 0.68072
# 7/7 [==============================] - 4s 590ms/step - loss: 0.6038 - accuracy: 0.6529 - val_loss: 0.6214 - val_accuracy: 0.6235
# Epoch 44/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6334 - accuracy: 0.6197
# Epoch 44: val_accuracy did not improve from 0.68072
# 7/7 [==============================] - 4s 590ms/step - loss: 0.6334 - accuracy: 0.6197 - val_loss: 0.6232 - val_accuracy: 0.6325
# Epoch 45/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6127 - accuracy: 0.6476
# Epoch 45: val_accuracy did not improve from 0.68072
# 7/7 [==============================] - 4s 589ms/step - loss: 0.6127 - accuracy: 0.6476 - val_loss: 0.6085 - val_accuracy: 0.6657
# Epoch 46/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6014 - accuracy: 0.6664
# Epoch 46: val_accuracy did not improve from 0.68072
# 7/7 [==============================] - 4s 588ms/step - loss: 0.6014 - accuracy: 0.6664 - val_loss: 0.6118 - val_accuracy: 0.6777
# Epoch 47/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6103 - accuracy: 0.6589
# Epoch 47: val_accuracy did not improve from 0.68072
# 7/7 [==============================] - 4s 590ms/step - loss: 0.6103 - accuracy: 0.6589 - val_loss: 0.6061 - val_accuracy: 0.6747
# Epoch 48/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6016 - accuracy: 0.6566
# Epoch 48: val_accuracy did not improve from 0.68072
# 7/7 [==============================] - 4s 589ms/step - loss: 0.6016 - accuracy: 0.6566 - val_loss: 0.6064 - val_accuracy: 0.6777
# Epoch 49/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5998 - accuracy: 0.6566
# Epoch 49: val_accuracy did not improve from 0.68072
# 7/7 [==============================] - 4s 589ms/step - loss: 0.5998 - accuracy: 0.6566 - val_loss: 0.6183 - val_accuracy: 0.6446
# Epoch 50/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5906 - accuracy: 0.6709
# Epoch 50: val_accuracy did not improve from 0.68072
# 7/7 [==============================] - 4s 590ms/step - loss: 0.5906 - accuracy: 0.6709 - val_loss: 0.6071 - val_accuracy: 0.6717
# Epoch 51/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6177 - accuracy: 0.6491
# Epoch 51: val_accuracy did not improve from 0.68072
# 7/7 [==============================] - 4s 589ms/step - loss: 0.6177 - accuracy: 0.6491 - val_loss: 0.6025 - val_accuracy: 0.6657
# Epoch 52/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5948 - accuracy: 0.6664
# Epoch 52: val_accuracy improved from 0.68072 to 0.68976, saving model to functional-first.h5
# 7/7 [==============================] - 4s 595ms/step - loss: 0.5948 - accuracy: 0.6664 - val_loss: 0.6007 - val_accuracy: 0.6898
# Epoch 53/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5948 - accuracy: 0.6589
# Epoch 53: val_accuracy did not improve from 0.68976
# 7/7 [==============================] - 4s 590ms/step - loss: 0.5948 - accuracy: 0.6589 - val_loss: 0.5998 - val_accuracy: 0.6898
# Epoch 54/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5933 - accuracy: 0.6574
# Epoch 54: val_accuracy did not improve from 0.68976
# 7/7 [==============================] - 4s 589ms/step - loss: 0.5933 - accuracy: 0.6574 - val_loss: 0.6120 - val_accuracy: 0.6476
# Epoch 55/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5873 - accuracy: 0.6762
# Epoch 55: val_accuracy did not improve from 0.68976
# 7/7 [==============================] - 4s 591ms/step - loss: 0.5873 - accuracy: 0.6762 - val_loss: 0.6003 - val_accuracy: 0.6807
# Epoch 56/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5868 - accuracy: 0.6732
# Epoch 56: val_accuracy did not improve from 0.68976
# 7/7 [==============================] - 4s 592ms/step - loss: 0.5868 - accuracy: 0.6732 - val_loss: 0.5999 - val_accuracy: 0.6687
# Epoch 57/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5878 - accuracy: 0.6619
# Epoch 57: val_accuracy did not improve from 0.68976
# 7/7 [==============================] - 4s 591ms/step - loss: 0.5878 - accuracy: 0.6619 - val_loss: 0.6252 - val_accuracy: 0.6386
# Epoch 58/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5834 - accuracy: 0.6777
# Epoch 58: val_accuracy improved from 0.68976 to 0.69277, saving model to functional-first.h5
# 7/7 [==============================] - 4s 597ms/step - loss: 0.5834 - accuracy: 0.6777 - val_loss: 0.6060 - val_accuracy: 0.6928
# Epoch 59/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5741 - accuracy: 0.6694
# Epoch 59: val_accuracy improved from 0.69277 to 0.69880, saving model to functional-first.h5
# 7/7 [==============================] - 4s 597ms/step - loss: 0.5741 - accuracy: 0.6694 - val_loss: 0.6073 - val_accuracy: 0.6988
# Epoch 60/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6093 - accuracy: 0.6476
# Epoch 60: val_accuracy did not improve from 0.69880
# 7/7 [==============================] - 4s 592ms/step - loss: 0.6093 - accuracy: 0.6476 - val_loss: 0.6000 - val_accuracy: 0.6747
# Epoch 61/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5727 - accuracy: 0.6860
# Epoch 61: val_accuracy improved from 0.69880 to 0.71687, saving model to functional-first.h5
# 7/7 [==============================] - 4s 596ms/step - loss: 0.5727 - accuracy: 0.6860 - val_loss: 0.5953 - val_accuracy: 0.7169
# Epoch 62/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6272 - accuracy: 0.6431
# Epoch 62: val_accuracy did not improve from 0.71687
# 7/7 [==============================] - 4s 592ms/step - loss: 0.6272 - accuracy: 0.6431 - val_loss: 0.6031 - val_accuracy: 0.6506
# Epoch 63/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5938 - accuracy: 0.6619
# Epoch 63: val_accuracy did not improve from 0.71687
# 7/7 [==============================] - 4s 590ms/step - loss: 0.5938 - accuracy: 0.6619 - val_loss: 0.5990 - val_accuracy: 0.6566
# Epoch 64/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5838 - accuracy: 0.6777
# Epoch 64: val_accuracy did not improve from 0.71687
# 7/7 [==============================] - 4s 591ms/step - loss: 0.5838 - accuracy: 0.6777 - val_loss: 0.6003 - val_accuracy: 0.6596
# Epoch 65/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5768 - accuracy: 0.6830
# Epoch 65: val_accuracy did not improve from 0.71687
# 7/7 [==============================] - 4s 590ms/step - loss: 0.5768 - accuracy: 0.6830 - val_loss: 0.5973 - val_accuracy: 0.6747
# Epoch 66/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5802 - accuracy: 0.6815
# Epoch 66: val_accuracy did not improve from 0.71687
# 7/7 [==============================] - 4s 591ms/step - loss: 0.5802 - accuracy: 0.6815 - val_loss: 0.5946 - val_accuracy: 0.6717
# Epoch 67/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5735 - accuracy: 0.6717
# Epoch 67: val_accuracy did not improve from 0.71687
# 7/7 [==============================] - 4s 591ms/step - loss: 0.5735 - accuracy: 0.6717 - val_loss: 0.5917 - val_accuracy: 0.6777
# Epoch 68/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5606 - accuracy: 0.7018
# Epoch 68: val_accuracy did not improve from 0.71687
# 7/7 [==============================] - 4s 591ms/step - loss: 0.5606 - accuracy: 0.7018 - val_loss: 0.6024 - val_accuracy: 0.6717
# Epoch 69/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5596 - accuracy: 0.7003
# Epoch 69: val_accuracy did not improve from 0.71687
# 7/7 [==============================] - 4s 592ms/step - loss: 0.5596 - accuracy: 0.7003 - val_loss: 0.5867 - val_accuracy: 0.7018
# Epoch 70/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5661 - accuracy: 0.7071
# Epoch 70: val_accuracy did not improve from 0.71687
# 7/7 [==============================] - 4s 592ms/step - loss: 0.5661 - accuracy: 0.7071 - val_loss: 0.6137 - val_accuracy: 0.6657
# Epoch 71/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5613 - accuracy: 0.6898
# Epoch 71: val_accuracy did not improve from 0.71687
# 7/7 [==============================] - 4s 593ms/step - loss: 0.5613 - accuracy: 0.6898 - val_loss: 0.5942 - val_accuracy: 0.6777

# %%
best_model = load_model(model_path)
best_model.evaluate([X_test, features_test], y_data_test)
# Out:
# 13/13 [==============================] - 1s 29ms/step - loss: 0.5929 - accuracy: 0.6827
# [0.5929100513458252, 0.682692289352417]

# %%
import matplotlib.pyplot as plt

y_acc = hist.history["val_accuracy"]
y_vloss = hist.history["val_loss"]
xs = np.arange(1, len(y_acc) + 1)

plt.figure(figsize = (12,8))
plt.plot(xs, y_acc, label = "Validation Accuracy")
plt.plot(xs, y_vloss, label = "Validation loss")
plt.legend(), plt.grid(), plt.xlabel("Epoch"), plt.title("functional First"), plt.ylim([0.4,1])
plt.show()

# %%
from sklearn.metrics import confusion_matrix
y_train_pred=best_model.predict([X_test, features_test])
yhat=[]
for data in y_train_pred:
  if data>=0.5:
    yhat.append(1)
  else:
    yhat.append(0)
yhat

# %%
cf = confusion_matrix(y_data_test, yhat)
print(cf)
# Out:
# [[115  69]
#  [ 63 169]]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
p = precision_score(y_data_test, yhat)
print(p)
r = recall_score(y_data_test, yhat)
print(r)
f1 = f1_score(y_data_test, yhat)
print(f1)
# Out:
# 0.7100840336134454
# 0.728448275862069
# 0.7191489361702127

# %% [markdown]
# # train_test dataset에 없는 다른 데이터로 모델 테스트

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/test/test_mfcc_15세65세_aug전.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data_other=np.array(result)
result_data_other.shape
# Out:
# (520, 30, 901)

# %%
features_other = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/test/test_df_15세65세_aug전.csv")
features_other = features_other.iloc[:,[4,5,6,7]]
features_other
# Out:
#      man  respiratory_condition  fever_muscle_pain  COVID-19
# 0      1                      1                  0         0
# 1      1                      1                  0         0
# 2      1                      0                  0         0
# 3      1                      0                  0         0
# 4      1                      0                  0         0
# ..   ...                    ...                ...       ...
# 515    0                      0                  1         1
# 516    0                      0                  0         1
# 517    0                      0                  0         1
# 518    0                      0                  1         1
# 519    0                      0                  1         1
#
# [520 rows x 4 columns]

# %%
feature_test_data = features_other.iloc[:,:-1].values
y_test_data = features_other.iloc[:,-1].values

# %%
y_train_pred=model.predict([result_data_other, feature_test_data])
yhat_test=[]
for data in y_train_pred:
  if data>=0.5:
    yhat_test.append(1)
  else:
    yhat_test.append(0)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
p = precision_score(y_test_data, yhat_test)
print(p)
r = recall_score(y_test_data, yhat_test)
print(r)
f1 = f1_score(y_test_data, yhat_test)
print(f1)
# Out:
# 0.5591836734693878
# 0.5269230769230769
# 0.5425742574257427

# %%
model.evaluate([result_data_other, feature_test_data], y_test_data)
# Out:
# 17/17 [==============================] - 0s 28ms/step - loss: 0.8094 - accuracy: 0.5558
# [0.8093618154525757, 0.5557692050933838]
