# %%
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.12)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Dropout, Flatten
from tensorflow.keras.layers import Dense, Concatenate
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pickle5 as pickle
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# # mmfc 불러오기

# %%
with open("/content/drive/MyDrive/multi/second_project/data/mfcc_data/mfcc_1565_final.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data=np.array(result)
result_data.shape
# Out:
# (2304, 30, 901)

# %% [markdown]
# ## covid19 여부 불러오기

# %%
y = pd.read_csv("/content/drive/MyDrive/multi/second_project/data/mfcc_data/Y_data_1516.csv").iloc[:,0]

# %% [markdown]
# ## feature 불러오기

# %%
features = pd.read_csv("/content/drive/MyDrive/multi/second_project/data/train_df_최종본_15세이상_65세미만.csv")
features = features.iloc[:,[4,5,6,7]]
feature_lst = []
for i in features.index:
    for _ in range(4):
        feature_lst.append(features.iloc[i,:].values)
features = pd.DataFrame(feature_lst)
features.shape
# Out:
# (2304, 4)

# %%
features.head(3)
# Out:
#    0  1  2  3
# 0  1  1  0  0
# 1  1  1  0  0
# 2  1  1  0  0

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    result_data, features, stratify = features, test_size = 0.2
)

# %%
features_train = Y_train.iloc[:,:-1].values
y_data_train = Y_train.iloc[:,-1].values

# %%
features_test = Y_test.iloc[:,:-1].values
y_data_test = Y_test.iloc[:,-1].values

# %%
# 각 입력에 대한 형태를 명시
img_input = Input(shape = (30,901,1), name = "X_train")
form_input = Input(shape = (3,), name = "features_train")

# %%
# 이미지 입력
x_1 = Conv2D(64, (3,3), activation = "relu")(img_input)
x_1 = Conv2D(64, (3,3), activation = "relu")(x_1)
x_1 = MaxPooling2D(pool_size=(2,2),strides = 2)(x_1)
x_1 = Conv2D(32, (3,3), activation = "relu")(x_1)
x_1 = Conv2D(32, (3,3), activation = "relu")(x_1)
x_1 = MaxPooling2D(pool_size=(2,2),strides = 2)(x_1)
x_1 = GlobalAveragePooling2D()(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = Conv2D(32, (3,3), activation = "relu")(img_input)
x_1 = Conv2D(32, (3,3), activation = "relu")(x_1)
x_1 = MaxPooling2D(pool_size=(2,2),strides = 2)(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = Dense(128, activation = "relu")(x_1)
x_1 = Dense(64, activation = "relu")(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = Flatten()(x_1)


# 피쳐 입력
x_2 = Dense(128, input_dim = 3 ,activation  = "relu")(form_input)
x_2 = Dense(64, activation = "relu")(x_2)
x_2 = Dense(32, activation = "relu")(x_2)

# %%
# 출력을 만들기 위해 모든 입력을 하나의 텐서로 합침
x = Concatenate()([x_1, x_2])

# %%
rate_pred = Dense(1, name = "covid", activation = "sigmoid")(x)

# %%
model = Model(inputs = [img_input, form_input],
              outputs = [rate_pred])

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  X_train (InputLayer)           [(None, 30, 901, 1)  0           []
#                                 ]
#
#  conv2d_4 (Conv2D)              (None, 28, 899, 32)  320         ['X_train[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 26, 897, 32)  9248        ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 13, 448, 32)  0          ['conv2d_5[0][0]']
#
#  dropout_1 (Dropout)            (None, 13, 448, 32)  0           ['max_pooling2d_2[0][0]']
#
#  dense (Dense)                  (None, 13, 448, 128  4224        ['dropout_1[0][0]']
#                                 )
#
#  features_train (InputLayer)    [(None, 3)]          0           []
#
#  dense_1 (Dense)                (None, 13, 448, 64)  8256        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 128)          512         ['features_train[0][0]']
#
#  dropout_2 (Dropout)            (None, 13, 448, 64)  0           ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 64)           8256        ['dense_2[0][0]']
#
#  flatten (Flatten)              (None, 372736)       0           ['dropout_2[0][0]']
#
#  dense_4 (Dense)                (None, 32)           2080        ['dense_3[0][0]']
#
#  concatenate (Concatenate)      (None, 372768)       0           ['flatten[0][0]',
#                                                                   'dense_4[0][0]']
#
#  covid (Dense)                  (None, 1)            372769      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 405,665
# Trainable params: 405,665
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = "adam",
              loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
model_path = "second-functional.h5"
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1, monitor = "val_loss")
es = EarlyStopping(patience=10, monitor = "val_loss")

# %%
hist = model.fit([X_train, features_train] , y_data_train,
                 epochs = 100, batch_size = 100,
                 validation_split=0.2, callbacks = [mc,es])
# Out:
# Epoch 1/100
# 15/15 [==============================] - ETA: 0s - loss: 24.4688 - accuracy: 0.5237
# Epoch 1: val_loss improved from inf to 2.43160, saving model to second-functional.h5
# 15/15 [==============================] - 8s 316ms/step - loss: 24.4688 - accuracy: 0.5237 - val_loss: 2.4316 - val_accuracy: 0.4715
# Epoch 2/100
# 15/15 [==============================] - ETA: 0s - loss: 1.0663 - accuracy: 0.5251
# Epoch 2: val_loss improved from 2.43160 to 0.71332, saving model to second-functional.h5
# 15/15 [==============================] - 3s 203ms/step - loss: 1.0663 - accuracy: 0.5251 - val_loss: 0.7133 - val_accuracy: 0.5257
# Epoch 3/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6802 - accuracy: 0.5706
# Epoch 3: val_loss improved from 0.71332 to 0.68499, saving model to second-functional.h5
# 15/15 [==============================] - 3s 212ms/step - loss: 0.6802 - accuracy: 0.5706 - val_loss: 0.6850 - val_accuracy: 0.5827
# Epoch 4/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6552 - accuracy: 0.6174
# Epoch 4: val_loss improved from 0.68499 to 0.66679, saving model to second-functional.h5
# 15/15 [==============================] - 3s 209ms/step - loss: 0.6552 - accuracy: 0.6174 - val_loss: 0.6668 - val_accuracy: 0.6070
# Epoch 5/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6245 - accuracy: 0.6737
# Epoch 5: val_loss improved from 0.66679 to 0.64735, saving model to second-functional.h5
# 15/15 [==============================] - 3s 206ms/step - loss: 0.6245 - accuracy: 0.6737 - val_loss: 0.6473 - val_accuracy: 0.6287
# Epoch 6/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5990 - accuracy: 0.6730
# Epoch 6: val_loss did not improve from 0.64735
# 15/15 [==============================] - 3s 189ms/step - loss: 0.5990 - accuracy: 0.6730 - val_loss: 0.6481 - val_accuracy: 0.6369
# Epoch 7/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5497 - accuracy: 0.7252
# Epoch 7: val_loss did not improve from 0.64735
# 15/15 [==============================] - 3s 187ms/step - loss: 0.5497 - accuracy: 0.7252 - val_loss: 0.6532 - val_accuracy: 0.6206
# Epoch 8/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4885 - accuracy: 0.7714
# Epoch 8: val_loss did not improve from 0.64735
# 15/15 [==============================] - 3s 187ms/step - loss: 0.4885 - accuracy: 0.7714 - val_loss: 0.6760 - val_accuracy: 0.6287
# Epoch 9/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4174 - accuracy: 0.8345
# Epoch 9: val_loss did not improve from 0.64735
# 15/15 [==============================] - 3s 188ms/step - loss: 0.4174 - accuracy: 0.8345 - val_loss: 0.6931 - val_accuracy: 0.6341
# Epoch 10/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3176 - accuracy: 0.8765
# Epoch 10: val_loss did not improve from 0.64735
# 15/15 [==============================] - 3s 189ms/step - loss: 0.3176 - accuracy: 0.8765 - val_loss: 0.8735 - val_accuracy: 0.5230
# Epoch 11/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2990 - accuracy: 0.8847
# Epoch 11: val_loss did not improve from 0.64735
# 15/15 [==============================] - 3s 189ms/step - loss: 0.2990 - accuracy: 0.8847 - val_loss: 0.7724 - val_accuracy: 0.6314
# Epoch 12/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9403
# Epoch 12: val_loss did not improve from 0.64735
# 15/15 [==============================] - 3s 188ms/step - loss: 0.1992 - accuracy: 0.9403 - val_loss: 0.8766 - val_accuracy: 0.5962
# Epoch 13/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9593
# Epoch 13: val_loss did not improve from 0.64735
# 15/15 [==============================] - 3s 188ms/step - loss: 0.1403 - accuracy: 0.9593 - val_loss: 0.9876 - val_accuracy: 0.6070
# Epoch 14/100
# 15/15 [==============================] - ETA: 0s - loss: 0.1248 - accuracy: 0.9600
# Epoch 14: val_loss did not improve from 0.64735
# 15/15 [==============================] - 3s 187ms/step - loss: 0.1248 - accuracy: 0.9600 - val_loss: 1.2423 - val_accuracy: 0.4986
# Epoch 15/100
# 15/15 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9756
# Epoch 15: val_loss did not improve from 0.64735
# 15/15 [==============================] - 3s 187ms/step - loss: 0.0939 - accuracy: 0.9756 - val_loss: 1.0577 - val_accuracy: 0.5881

# %%
y_acc = hist.history["val_accuracy"]
y_vloss = hist.history["val_loss"]
xs = np.arange(1, len(y_acc) + 1)

plt.figure(figsize = (8,6))
plt.plot(xs, y_acc, label = "Validation Accuracy")
plt.plot(xs, y_vloss, label = "Validation loss")
plt.legend(), plt.grid(), plt.xlabel("Epoch"), plt.title("First Model"), plt.ylim([0,1])
plt.show()

# %%
model = load_model(model_path)
model.evaluate([X_test, features_test], y_data_test)
# Out:
# 15/15 [==============================] - 1s 26ms/step - loss: 0.6531 - accuracy: 0.6182
# [0.6530627608299255, 0.6182212829589844]
