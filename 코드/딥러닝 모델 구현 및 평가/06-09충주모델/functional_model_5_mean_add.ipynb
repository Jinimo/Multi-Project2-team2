# %%
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.12)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Dropout, Flatten
from tensorflow.keras.layers import Dense, Concatenate
from tensorflow.keras.optimizers import RMSprop, SGD, Adadelta
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pickle5 as pickle
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# # mmfc 불러오기

# %%
with open("/content/drive/MyDrive/multi/second_project/data/mfcc_data/mfcc_1565_final.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data=np.array(result)
result_data.shape
# Out:
# (2304, 30, 901)

# %% [markdown]
# ## covid19 여부 불러오기

# %%
y = pd.read_csv("/content/drive/MyDrive/multi/second_project/data/mfcc_data/Y_data_1516.csv").iloc[:,0]

# %% [markdown]
# ## feature 불러오기

# %%
features = pd.read_csv("/content/drive/MyDrive/multi/second_project/data/train_df_최종본_15세이상_65세미만.csv")
features = features.iloc[:,[4,5,6,7]]
feature_lst = []
for i in features.index:
    for _ in range(4):
        feature_lst.append(features.iloc[i,:].values)
features = pd.DataFrame(feature_lst)
features.shape
# Out:
# (2304, 4)

# %%
means = pd.read_csv("/content/drive/MyDrive/multi/second_project/data/mfcc_mean_lst2.csv").set_index("Unnamed: 0").reset_index(drop = "True")
means.shape
# Out:
# (2304, 30)

# %%
features = pd.concat([means, features], axis = 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    result_data, features, stratify = features.iloc[:,-1], test_size = 0.2, random_state = 2022
)

# %%
X_train = X_train/255
X_test = X_test/255

# %%
features_train = Y_train.iloc[:,:-1].values
y_data_train = Y_train.iloc[:,-1].values

# %%
features_test = Y_test.iloc[:,:-1].values
y_data_test = Y_test.iloc[:,-1].values

# %%
# 각 입력에 대한 형태를 명시
img_input = Input(shape = (30,901,1), name = "X_train")
form_input = Input(shape = (33,), name = "features_train")

# %%
# 이미지 입력
x_1 = Conv2D(64, (3,3), activation = "relu")(img_input)
x_1 = Conv2D(64, (3,3), activation = "relu")(x_1)
x_1 = MaxPooling2D(pool_size=(2,2),strides = 2)(x_1)
x_1 = Conv2D(32, (3,3), activation = "relu")(x_1)
x_1 = Conv2D(32, (3,3), activation = "relu")(x_1)
x_1 = MaxPooling2D(pool_size=(2,2),strides = 2)(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = Conv2D(32, (3,3), activation = "relu")(img_input)
x_1 = Conv2D(32, (3,3), activation = "relu")(x_1)
x_1 = MaxPooling2D(pool_size=(2,2),strides = 2)(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = Dense(128, activation = "relu")(x_1)
x_1 = Dense(64, activation = "relu")(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = Flatten()(x_1)


# 피쳐 입력
x_2 = Dense(128, input_dim = 33 ,activation  = "relu")(form_input)
x_2 = Dense(64, activation = "relu")(x_2)
x_2 = Dense(32, activation = "relu")(x_2)

# %%
# 출력을 만들기 위해 모든 입력을 하나의 텐서로 합침
x = Concatenate()([x_1, x_2])

# %%
rate_pred = Dense(1, name = "covid", activation = "sigmoid")(x)

# %%
model = Model(inputs = [img_input, form_input],
              outputs = [rate_pred])

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  X_train (InputLayer)           [(None, 30, 901, 1)  0           []
#                                 ]
#
#  conv2d_4 (Conv2D)              (None, 28, 899, 32)  320         ['X_train[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 26, 897, 32)  9248        ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 13, 448, 32)  0          ['conv2d_5[0][0]']
#
#  dropout_1 (Dropout)            (None, 13, 448, 32)  0           ['max_pooling2d_2[0][0]']
#
#  dense (Dense)                  (None, 13, 448, 128  4224        ['dropout_1[0][0]']
#                                 )
#
#  features_train (InputLayer)    [(None, 33)]         0           []
#
#  dense_1 (Dense)                (None, 13, 448, 64)  8256        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 128)          4352        ['features_train[0][0]']
#
#  dropout_2 (Dropout)            (None, 13, 448, 64)  0           ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 64)           8256        ['dense_2[0][0]']
#
#  flatten (Flatten)              (None, 372736)       0           ['dropout_2[0][0]']
#
#  dense_4 (Dense)                (None, 32)           2080        ['dense_3[0][0]']
#
#  concatenate (Concatenate)      (None, 372768)       0           ['flatten[0][0]',
#                                                                   'dense_4[0][0]']
#
#  covid (Dense)                  (None, 1)            372769      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 409,505
# Trainable params: 409,505
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = Adadelta(lr=2.0, rho=0.95, epsilon=None, decay=1e-4),
              loss = "binary_crossentropy", metrics = ["accuracy"])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adadelta.py:74: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adadelta, self).__init__(name, **kwargs)

# %%
model_path = "second-functional.h5"
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1, monitor = "val_loss")
es = EarlyStopping(patience=10, monitor = "val_loss")

# %%
hist = model.fit([X_train, features_train] , y_data_train,
                 epochs = 100, batch_size = 100,
                 validation_split=0.2, callbacks = [mc,es])
# Out:
# Epoch 1/100
# 15/15 [==============================] - ETA: 0s - loss: 0.7909 - accuracy: 0.4932
# Epoch 1: val_loss improved from inf to 0.69505, saving model to second-functional.h5
# 15/15 [==============================] - 8s 261ms/step - loss: 0.7909 - accuracy: 0.4932 - val_loss: 0.6951 - val_accuracy: 0.4824
# Epoch 2/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6943 - accuracy: 0.5068
# Epoch 2: val_loss improved from 0.69505 to 0.69270, saving model to second-functional.h5
# 15/15 [==============================] - 3s 177ms/step - loss: 0.6943 - accuracy: 0.5068 - val_loss: 0.6927 - val_accuracy: 0.5176
# Epoch 3/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5183
# Epoch 3: val_loss did not improve from 0.69270
# 15/15 [==============================] - 3s 173ms/step - loss: 0.6930 - accuracy: 0.5183 - val_loss: 0.6943 - val_accuracy: 0.4824
# Epoch 4/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5183
# Epoch 4: val_loss improved from 0.69270 to 0.69183, saving model to second-functional.h5
# 15/15 [==============================] - 3s 176ms/step - loss: 0.6925 - accuracy: 0.5183 - val_loss: 0.6918 - val_accuracy: 0.5257
# Epoch 5/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.5027
# Epoch 5: val_loss improved from 0.69183 to 0.69106, saving model to second-functional.h5
# 15/15 [==============================] - 3s 177ms/step - loss: 0.6936 - accuracy: 0.5027 - val_loss: 0.6911 - val_accuracy: 0.5122
# Epoch 6/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6900 - accuracy: 0.5244
# Epoch 6: val_loss did not improve from 0.69106
# 15/15 [==============================] - 3s 175ms/step - loss: 0.6900 - accuracy: 0.5244 - val_loss: 0.6931 - val_accuracy: 0.5176
# Epoch 7/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.5251
# Epoch 7: val_loss did not improve from 0.69106
# 15/15 [==============================] - 3s 175ms/step - loss: 0.6937 - accuracy: 0.5251 - val_loss: 0.6922 - val_accuracy: 0.5257
# Epoch 8/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6866 - accuracy: 0.5400
# Epoch 8: val_loss did not improve from 0.69106
# 15/15 [==============================] - 3s 175ms/step - loss: 0.6866 - accuracy: 0.5400 - val_loss: 0.6933 - val_accuracy: 0.5366
# Epoch 9/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6767 - accuracy: 0.5855
# Epoch 9: val_loss did not improve from 0.69106
# 15/15 [==============================] - 3s 176ms/step - loss: 0.6767 - accuracy: 0.5855 - val_loss: 0.7012 - val_accuracy: 0.4851
# Epoch 10/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6655 - accuracy: 0.6065
# Epoch 10: val_loss did not improve from 0.69106
# 15/15 [==============================] - 3s 176ms/step - loss: 0.6655 - accuracy: 0.6065 - val_loss: 0.7282 - val_accuracy: 0.4797
# Epoch 11/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6369 - accuracy: 0.6113
# Epoch 11: val_loss did not improve from 0.69106
# 15/15 [==============================] - 3s 176ms/step - loss: 0.6369 - accuracy: 0.6113 - val_loss: 0.8411 - val_accuracy: 0.4444
# Epoch 12/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6257 - accuracy: 0.6377
# Epoch 12: val_loss did not improve from 0.69106
# 15/15 [==============================] - 3s 177ms/step - loss: 0.6257 - accuracy: 0.6377 - val_loss: 0.7219 - val_accuracy: 0.5203
# Epoch 13/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6278 - accuracy: 0.6615
# Epoch 13: val_loss did not improve from 0.69106
# 15/15 [==============================] - 3s 176ms/step - loss: 0.6278 - accuracy: 0.6615 - val_loss: 0.6983 - val_accuracy: 0.5257
# Epoch 14/100
# 15/15 [==============================] - ETA: 0s - loss: 0.6148 - accuracy: 0.6744
# Epoch 14: val_loss did not improve from 0.69106
# 15/15 [==============================] - 3s 176ms/step - loss: 0.6148 - accuracy: 0.6744 - val_loss: 0.7171 - val_accuracy: 0.5122
# Epoch 15/100
# 15/15 [==============================] - ETA: 0s - loss: 0.5390 - accuracy: 0.7252
# Epoch 15: val_loss did not improve from 0.69106
# 15/15 [==============================] - 3s 177ms/step - loss: 0.5390 - accuracy: 0.7252 - val_loss: 0.8134 - val_accuracy: 0.5095

# %%
y_acc = hist.history["val_accuracy"]
y_vloss = hist.history["val_loss"]
xs = np.arange(1, len(y_acc) + 1)

plt.figure(figsize = (8,6))
plt.plot(xs, y_acc, label = "Validation Accuracy")
plt.plot(xs, y_vloss, label = "Validation loss")
plt.legend(), plt.grid(), plt.xlabel("Epoch"), plt.title("First Model"), plt.ylim([0,1])
plt.show()

# %%
model = load_model(model_path)
model.evaluate([X_test, features_test], y_data_test)
# Out:
# 15/15 [==============================] - 1s 25ms/step - loss: 0.6932 - accuracy: 0.4902
# [0.693244218826294, 0.49023860692977905]
