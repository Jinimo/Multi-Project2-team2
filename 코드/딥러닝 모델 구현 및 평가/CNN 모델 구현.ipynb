# %%
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.12)

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import pickle5 as pickle
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
import tensorflow as tf
seed=2022
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
df=pd.read_csv('/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/mfcc/Y_data_1516.csv')

# %%
y=df.iloc[:,0]

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/mfcc/mfcc_1565_data.pickle","rb") as fr:
    data = pickle.load(fr)

length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data=np.array(result)
X=result_data

# %%
X_train, X_test, y_train, y_test=train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=seed
)

# %%
X_train.shape
# Out:
# (1843, 30, 901)

# %%
model=Sequential([
       Conv2D(256, kernel_size=(3,3), input_shape=(30, 901, 1), activation='relu'),
       Conv2D(256, (3,3), activation='relu'),
       MaxPooling2D(),    
       Dropout(0.25),
       Conv2D(128, (3,3), activation='relu'),
       Conv2D(128, (3,3), activation='relu'),
       MaxPooling2D(),    
       Flatten(),
       Dense(128, activation='relu'),
       Dropout(0.5),
       Dense(64, activation='relu'),
       Dropout(0.5),
       Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 28, 899, 256)      2560
#
#  conv2d_19 (Conv2D)          (None, 26, 897, 256)      590080
#
#  max_pooling2d_11 (MaxPoolin  (None, 13, 448, 256)     0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 13, 448, 256)      0
#
#  conv2d_20 (Conv2D)          (None, 11, 446, 128)      295040
#
#  conv2d_21 (Conv2D)          (None, 9, 444, 128)       147584
#
#  max_pooling2d_12 (MaxPoolin  (None, 4, 222, 128)      0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 113664)            0
#
#  dense_10 (Dense)            (None, 128)               14549120
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 64)                8256
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_12 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 15,592,705
# Trainable params: 15,592,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_path='best-fashion-mnist-cnn-v1.h5'
mc=ModelCheckpoint(model_path, monitor='val_loss', save_best_only=True, verbose=1)
es=EarlyStopping(patience=10)

# %%
model.compile('adam', 'binary_crossentropy', ['accuracy'])

hist=model.fit(
    X_train, y_train, validation_split=0.2, epochs=100, batch_size=50, callbacks=[mc, es]
)
# Out:
# Epoch 1/100
# 30/30 [==============================] - ETA: 0s - loss: 2.4583 - accuracy: 0.4925
# Epoch 1: val_loss improved from inf to 0.69323, saving model to best-fashion-mnist-cnn-v1.h5
# 30/30 [==============================] - 53s 1s/step - loss: 2.4583 - accuracy: 0.4925 - val_loss: 0.6932 - val_accuracy: 0.4824
# Epoch 2/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4763
# Epoch 2: val_loss improved from 0.69323 to 0.69316, saving model to best-fashion-mnist-cnn-v1.h5
# 30/30 [==============================] - 32s 1s/step - loss: 0.6933 - accuracy: 0.4763 - val_loss: 0.6932 - val_accuracy: 0.4824
# Epoch 3/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4878
# Epoch 3: val_loss did not improve from 0.69316
# 30/30 [==============================] - 32s 1s/step - loss: 0.6933 - accuracy: 0.4878 - val_loss: 0.6932 - val_accuracy: 0.4824
# Epoch 4/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5000
# Epoch 4: val_loss did not improve from 0.69316
# 30/30 [==============================] - 32s 1s/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6934 - val_accuracy: 0.4824
# Epoch 5/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.4973
# Epoch 5: val_loss did not improve from 0.69316
# 30/30 [==============================] - 32s 1s/step - loss: 0.6931 - accuracy: 0.4973 - val_loss: 0.6933 - val_accuracy: 0.4824
# Epoch 6/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5014
# Epoch 6: val_loss did not improve from 0.69316
# 30/30 [==============================] - 32s 1s/step - loss: 0.6931 - accuracy: 0.5014 - val_loss: 0.6932 - val_accuracy: 0.4824
# Epoch 7/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5027
# Epoch 7: val_loss did not improve from 0.69316
# 30/30 [==============================] - 32s 1s/step - loss: 0.6931 - accuracy: 0.5027 - val_loss: 0.6933 - val_accuracy: 0.4824
# Epoch 8/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4885
# Epoch 8: val_loss did not improve from 0.69316
# 30/30 [==============================] - 32s 1s/step - loss: 0.6933 - accuracy: 0.4885 - val_loss: 0.6933 - val_accuracy: 0.4824
# Epoch 9/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4993
# Epoch 9: val_loss did not improve from 0.69316
# 30/30 [==============================] - 32s 1s/step - loss: 0.6932 - accuracy: 0.4993 - val_loss: 0.6933 - val_accuracy: 0.4824
# Epoch 10/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5136
# Epoch 10: val_loss did not improve from 0.69316
# 30/30 [==============================] - 32s 1s/step - loss: 0.6932 - accuracy: 0.5136 - val_loss: 0.6934 - val_accuracy: 0.4824
# Epoch 11/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4858
# Epoch 11: val_loss did not improve from 0.69316
# 30/30 [==============================] - 32s 1s/step - loss: 0.6934 - accuracy: 0.4858 - val_loss: 0.6933 - val_accuracy: 0.4824
# Epoch 12/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5047
# Epoch 12: val_loss did not improve from 0.69316
# 30/30 [==============================] - 32s 1s/step - loss: 0.6931 - accuracy: 0.5047 - val_loss: 0.6934 - val_accuracy: 0.4824

# %%
best_model=load_model(model_path)
best_model.evaluate(X_test, y_test)
# Out:
# 15/15 [==============================] - 6s 263ms/step - loss: 0.6931 - accuracy: 0.4989
# [0.6931480765342712, 0.4989154040813446]
